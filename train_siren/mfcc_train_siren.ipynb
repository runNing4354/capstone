# %%
import librosa 
import numpy as np
import pandas as pd
import os

max = 0

def mfcc_extraction(file_name):
   
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        
        if len(audio)/sample_rate > 2:
            audio = audio[ : sample_rate*2]
        
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccsscaled = np.mean(mfccs.T,axis=0)
        global max
        if mfccs.shape[1] > max:
            max = mfccs.shape[1]

    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
     
    return mfccsscaled

# %%
# 데이터셋 path 지정
fulldatasetpath = "C:\\Users\\taemi\\capstone\\data\\2_siren\\sounddata"
metadata = pd.read_csv("C:\\Users\\taemi\\capstone\\data\\2_siren\\metadata_2.csv")

features = []

    
# 각 소리에 대해 feature를 추출
for index, row in metadata.iterrows():
    
    filename = os.path.join(os.path.abspath(fulldatasetpath)+'/'+str(row["filename"]))
    classname = row["class"]
    data = mfcc_extraction(filename)
    
    features.append([data, classname])
    

featuresdf = pd.DataFrame(features, columns=['feature','class'])

print('Finished feature extraction from ', len(featuresdf), ' files') 
print('Max :',max)
# Out:
# C:\Users\taemi\anaconda3\envs\py38\lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# C:\Users\taemi\anaconda3\envs\py38\lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# Finished feature extraction from  1177  files
# Max : 87

# %%
import pandas as pd
from collections import Counter
from matplotlib import pyplot

#클래스별 데이터 갯수 표로 표시
data = featuresdf.values
y = data[:, -1]

def count_and_plot(y): 
    counter = Counter(y)
    for k,v in counter.items():
        print('Class=%s, n=%d (%.3f%%)' % (k, v, v / len(y) * 100))
    pyplot.bar(counter.keys(), counter.values(), width=0.3)
    pyplot.xticks(np.arange(0,4), labels=counter.keys(), rotation=90)
    pyplot.show()
    
    return v

data = featuresdf.values
y = data[:, -1]

count_and_plot(y)
# Out:
# Class=burglarAlarm, n=277 (23.534%)
# Class=other, n=300 (25.489%)
# Class=emergencyAlarm, n=300 (25.489%)
# Class=fireAlarm, n=300 (25.489%)
# 300

# %%
# extract feature 함수 재정의
import numpy as np
import librosa.display
max_pad_len = 87
test_num = 0

def mfcc_extraction(file_name):
    try:
        audio, sample_rate = librosa.load(file_name, res_type = 'kaiser_fast')
        
        if len(audio)/sample_rate > 2:
            audio = audio[ : sample_rate*2]
            
        mfccs = librosa.feature.mfcc(y=audio, sr = sample_rate, n_mfcc = 40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width = ((0, 0), (0, pad_width)), mode = 'constant')
    
    except Exception as e:
        print("Error 발생: ", file_name)
        return None
    
    return mfccs

# %%
import os

# 데이터셋 path 지정
fulldatasetpath = "C:\\Users\\taemi\\capstone\\data\\2_siren\\sounddata"

metadata = pd.read_csv("C:\\Users\\taemi\\capstone\\data\\2_siren\\metadata_2.csv")

features = []

# 각 소리에 대해 feature를 추출
for index, row in metadata.iterrows():
    
    file_name = os.path.join(os.path.abspath(fulldatasetpath)+'/'+str(row["filename"]))
    classname = row['class']
    data = mfcc_extraction(file_name)
        
        
    features.append([data, classname])
   
 


featuresdf = pd.DataFrame(features, columns=['feature','class'])
print('Finished feature extraction from ', len(featuresdf), ' files')
# Out:
# C:\Users\taemi\anaconda3\envs\py38\lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# Finished feature extraction from  1177  files

# %%
featuresdf['feature'][0]
# Out:
# array([[-5.4330090e+02, -4.3677374e+02, -4.0589499e+02, ...,
#         -3.7296265e+02, -3.7294229e+02, -3.9025342e+02],
#        [ 9.5736023e+01,  1.4785699e+02,  1.5878833e+02, ...,
#          1.3531134e+02,  1.3772437e+02,  1.2696220e+02],
#        [ 3.4527063e+00, -2.7654068e+01, -3.9978912e+01, ...,
#         -3.8897896e+01, -3.7136711e+01, -2.9035774e+01],
#        ...,
#        [-9.0436256e-01,  6.4548416e+00,  6.0487127e+00, ...,
#          4.7997255e+00,  7.7262335e+00,  5.9409103e+00],
#        [ 1.2287843e-01,  1.3230704e-01,  1.3226079e+00, ...,
#         -4.9817295e+00, -5.5927892e+00, -3.7858205e+00],
#        [ 8.0644244e-01, -2.0949912e-01, -8.7798530e-01, ...,
#         -7.2637415e+00, -7.0889072e+00, -6.4121413e+00]], dtype=float32)

# %%
import librosa.display
from matplotlib import pyplot as plt

plt.figure()
librosa.display.specshow(featuresdf['feature'][300], sr = 22050, x_axis='time')
plt.colorbar()
plt.title(featuresdf['class'][300])
# Out:
# Text(0.5, 1.0, 'burglarAlarm')

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import numpy as np
import pandas as pd


# Pandas로 저장된 각 열을 np.array로 반환
# X는 MFCC의 데이터
X = np.array(featuresdf.feature.tolist())
# Y는 그 데이터의 Label이 저장됨
y = np.array(featuresdf['class'].tolist())

# Tensorflow에 Label이 사용될 수 있도록 Label을 숫자로 인코딩 해준다.
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y))

# Test 데이터와 Train 데이터로 2:8로 나눈다.(셔플값이 디폴트이기 때문에 굳이 설정안해도 됨)
x_train, x_val, y_train, y_val = train_test_split(X, yy, test_size=0.1, random_state=1)
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.12222, random_state=1)

# %%
num_rows = 40
num_columns = 87
num_channels = 1

print("train data shape")
print(x_train.shape)
print(x_test.shape)
print(x_val.shape)

x_train = x_train.reshape(x_train.shape[0], num_rows, num_columns, num_channels)
x_test = x_test.reshape(x_test.shape[0], num_rows, num_columns, num_channels)
x_val = x_val.reshape(x_val.shape[0], num_rows, num_columns, num_channels)

print("\ntrain data reshape 결과")
print(x_train.shape)
print(x_test.shape)
print(x_val.shape)
# Out:
# train data shape
# (929, 40, 87)
# (130, 40, 87)
# (118, 40, 87)
#
# train data reshape 결과
# (929, 40, 87, 1)
# (130, 40, 87, 1)
# (118, 40, 87, 1)

# %%
# Out:
# 12

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D,Convolution2D, MaxPooling2D, GlobalAveragePooling2D, Dropout,LeakyReLU, BatchNormalization
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.utils import np_utils
from sklearn import metrics

num_labels = yy.shape[1]
filter_size = 2

# HyperParameter
EPOCHS = 1000
BATCH_SIZE = 512
MODEL_SAVE = "C:\\Users\\taemi\\capstone\\best_weight_model"
if not os.path.exists(MODEL_SAVE):
    os.mkdir(MODEL_SAVE)
    
checkpoint = ModelCheckpoint(filepath="{}/siren_mfcc.h5".format(MODEL_SAVE), monitor="val_loss",
                             verbose=1, save_best_only=True)

ealrystopping = EarlyStopping(monitor="val_loss", patience=20)

#CNN모델 구현
model = Sequential([
    Conv2D(16, 4, padding="same", input_shape=(num_rows, num_columns, num_channels), activation=LeakyReLU(0.1)),
    MaxPooling2D(),
    Dropout(0.2),
    Conv2D(32, 1, activation="relu"),
    Conv2D(64, 2, activation="relu"),
    MaxPooling2D(),
    Dropout(0.2),
    Conv2D(128, 4, activation=LeakyReLU(0.1)),
    MaxPooling2D(),
    Dropout(0.2),
    GlobalAveragePooling2D(),
    Dense(512, activation="relu"),
    Dropout(0.2),
    Dense(1024, activation="relu"),
    Dropout(0.2),
    Dense(num_labels, activation="softmax")])



#컴파일
model.compile(loss = 'categorical_crossentropy', metrics = ['accuracy'], optimizer = 'adam')  
model.summary()
history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(x_val, y_val),
          callbacks=[checkpoint, ealrystopping], verbose=1)

score = model.evaluate(x_test, y_test, verbose = 1)
accuracy = 100 * score[1]

print('Pre-training accuracy: %.4f%%' % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 40, 87, 16)        272
#
#  max_pooling2d (MaxPooling2D  (None, 20, 43, 16)       0
#  )
#
#  dropout (Dropout)           (None, 20, 43, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 20, 43, 32)        544
#
#  conv2d_2 (Conv2D)           (None, 19, 42, 64)        8256
#
#  max_pooling2d_1 (MaxPooling  (None, 9, 21, 64)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 9, 21, 64)         0
#
#  conv2d_3 (Conv2D)           (None, 6, 18, 128)        131200
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 9, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 3, 9, 128)         0
#
#  global_average_pooling2d (G  (None, 128)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               66048
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1024)              525312
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 735,732
# Trainable params: 735,732
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 2/2 [==============================] - ETA: 0s - loss: 2.6860 - accuracy: 0.2551
# Epoch 1: val_loss improved from inf to 2.39577, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 4s 678ms/step - loss: 2.6860 - accuracy: 0.2551 - val_loss: 2.3958 - val_accuracy: 0.2458
# Epoch 2/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 2.9734 - accuracy: 0.2500
# Epoch 2: val_loss improved from 2.39577 to 1.30539, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 2.4319 - accuracy: 0.3057 - val_loss: 1.3054 - val_accuracy: 0.3983
# Epoch 3/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4085 - accuracy: 0.3926
# Epoch 3: val_loss improved from 1.30539 to 1.19055, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 84ms/step - loss: 1.3549 - accuracy: 0.3617 - val_loss: 1.1905 - val_accuracy: 0.3390
# Epoch 4/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2075 - accuracy: 0.3926
# Epoch 4: val_loss improved from 1.19055 to 1.14607, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 1.1791 - accuracy: 0.4478 - val_loss: 1.1461 - val_accuracy: 0.4915
# Epoch 5/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0747 - accuracy: 0.5508
# Epoch 5: val_loss improved from 1.14607 to 1.01032, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 93ms/step - loss: 1.0556 - accuracy: 0.5856 - val_loss: 1.0103 - val_accuracy: 0.6102
# Epoch 6/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9258 - accuracy: 0.6250
# Epoch 6: val_loss improved from 1.01032 to 0.80948, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 82ms/step - loss: 0.8682 - accuracy: 0.6502 - val_loss: 0.8095 - val_accuracy: 0.8220
# Epoch 7/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7157 - accuracy: 0.8145
# Epoch 7: val_loss improved from 0.80948 to 0.66680, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 0.7094 - accuracy: 0.7976 - val_loss: 0.6668 - val_accuracy: 0.8051
# Epoch 8/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5927 - accuracy: 0.8164
# Epoch 8: val_loss improved from 0.66680 to 0.57584, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 82ms/step - loss: 0.5505 - accuracy: 0.8159 - val_loss: 0.5758 - val_accuracy: 0.7542
# Epoch 9/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4906 - accuracy: 0.7930
# Epoch 9: val_loss improved from 0.57584 to 0.45233, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 82ms/step - loss: 0.4686 - accuracy: 0.8062 - val_loss: 0.4523 - val_accuracy: 0.7712
# Epoch 10/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3822 - accuracy: 0.8477
# Epoch 10: val_loss improved from 0.45233 to 0.36722, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 81ms/step - loss: 0.3914 - accuracy: 0.8439 - val_loss: 0.3672 - val_accuracy: 0.8390
# Epoch 11/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3870 - accuracy: 0.8477
# Epoch 11: val_loss did not improve from 0.36722
# 2/2 [==============================] - 0s 46ms/step - loss: 0.3398 - accuracy: 0.8654 - val_loss: 0.3723 - val_accuracy: 0.7966
# Epoch 12/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3108 - accuracy: 0.8457
# Epoch 12: val_loss improved from 0.36722 to 0.30479, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 84ms/step - loss: 0.3137 - accuracy: 0.8515 - val_loss: 0.3048 - val_accuracy: 0.8814
# Epoch 13/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2972 - accuracy: 0.8652
# Epoch 13: val_loss improved from 0.30479 to 0.27730, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 84ms/step - loss: 0.2817 - accuracy: 0.8741 - val_loss: 0.2773 - val_accuracy: 0.8390
# Epoch 14/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2711 - accuracy: 0.8848
# Epoch 14: val_loss improved from 0.27730 to 0.25502, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 82ms/step - loss: 0.2565 - accuracy: 0.8902 - val_loss: 0.2550 - val_accuracy: 0.9068
# Epoch 15/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2299 - accuracy: 0.8926
# Epoch 15: val_loss improved from 0.25502 to 0.24399, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 82ms/step - loss: 0.2170 - accuracy: 0.9031 - val_loss: 0.2440 - val_accuracy: 0.9068
# Epoch 16/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1519 - accuracy: 0.9355
# Epoch 16: val_loss improved from 0.24399 to 0.18813, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1861 - accuracy: 0.9214 - val_loss: 0.1881 - val_accuracy: 0.9492
# Epoch 17/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1707 - accuracy: 0.9355
# Epoch 17: val_loss improved from 0.18813 to 0.16138, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1655 - accuracy: 0.9333 - val_loss: 0.1614 - val_accuracy: 0.9322
# Epoch 18/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1377 - accuracy: 0.9434
# Epoch 18: val_loss improved from 0.16138 to 0.14844, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1331 - accuracy: 0.9429 - val_loss: 0.1484 - val_accuracy: 0.9407
# Epoch 19/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1073 - accuracy: 0.9590
# Epoch 19: val_loss did not improve from 0.14844
# 2/2 [==============================] - 0s 53ms/step - loss: 0.1153 - accuracy: 0.9548 - val_loss: 0.1530 - val_accuracy: 0.9492
# Epoch 20/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1101 - accuracy: 0.9492
# Epoch 20: val_loss improved from 0.14844 to 0.13573, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1172 - accuracy: 0.9505 - val_loss: 0.1357 - val_accuracy: 0.9407
# Epoch 21/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1004 - accuracy: 0.9609
# Epoch 21: val_loss improved from 0.13573 to 0.11378, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1086 - accuracy: 0.9591 - val_loss: 0.1138 - val_accuracy: 0.9407
# Epoch 22/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1037 - accuracy: 0.9570
# Epoch 22: val_loss did not improve from 0.11378
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0980 - accuracy: 0.9623 - val_loss: 0.1304 - val_accuracy: 0.9492
# Epoch 23/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0856 - accuracy: 0.9648
# Epoch 23: val_loss improved from 0.11378 to 0.10437, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0883 - accuracy: 0.9634 - val_loss: 0.1044 - val_accuracy: 0.9407
# Epoch 24/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0726 - accuracy: 0.9688
# Epoch 24: val_loss did not improve from 0.10437
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0782 - accuracy: 0.9688 - val_loss: 0.1139 - val_accuracy: 0.9492
# Epoch 25/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0550 - accuracy: 0.9785
# Epoch 25: val_loss did not improve from 0.10437
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0655 - accuracy: 0.9763 - val_loss: 0.1059 - val_accuracy: 0.9492
# Epoch 26/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0663 - accuracy: 0.9746
# Epoch 26: val_loss did not improve from 0.10437
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0663 - accuracy: 0.9731 - val_loss: 0.1076 - val_accuracy: 0.9576
# Epoch 27/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0714 - accuracy: 0.9707
# Epoch 27: val_loss did not improve from 0.10437
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0684 - accuracy: 0.9677 - val_loss: 0.1083 - val_accuracy: 0.9576
# Epoch 28/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0603 - accuracy: 0.9863
# Epoch 28: val_loss improved from 0.10437 to 0.10102, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0593 - accuracy: 0.9839 - val_loss: 0.1010 - val_accuracy: 0.9576
# Epoch 29/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0434 - accuracy: 0.9844
# Epoch 29: val_loss improved from 0.10102 to 0.09406, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0496 - accuracy: 0.9828 - val_loss: 0.0941 - val_accuracy: 0.9576
# Epoch 30/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0396 - accuracy: 0.9824
# Epoch 30: val_loss improved from 0.09406 to 0.09201, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0546 - accuracy: 0.9763 - val_loss: 0.0920 - val_accuracy: 0.9576
# Epoch 31/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0531 - accuracy: 0.9785
# Epoch 31: val_loss did not improve from 0.09201
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0473 - accuracy: 0.9795 - val_loss: 0.1167 - val_accuracy: 0.9407
# Epoch 32/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0330 - accuracy: 0.9883
# Epoch 32: val_loss did not improve from 0.09201
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0375 - accuracy: 0.9849 - val_loss: 0.0930 - val_accuracy: 0.9492
# Epoch 33/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0410 - accuracy: 0.9824
# Epoch 33: val_loss improved from 0.09201 to 0.08700, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 88ms/step - loss: 0.0372 - accuracy: 0.9860 - val_loss: 0.0870 - val_accuracy: 0.9492
# Epoch 34/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0375 - accuracy: 0.9844
# Epoch 34: val_loss improved from 0.08700 to 0.07946, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0385 - accuracy: 0.9795 - val_loss: 0.0795 - val_accuracy: 0.9492
# Epoch 35/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0264 - accuracy: 0.9883
# Epoch 35: val_loss did not improve from 0.07946
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0263 - accuracy: 0.9882 - val_loss: 0.1092 - val_accuracy: 0.9492
# Epoch 36/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0458 - accuracy: 0.9785
# Epoch 36: val_loss did not improve from 0.07946
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0403 - accuracy: 0.9828 - val_loss: 0.0803 - val_accuracy: 0.9492
# Epoch 37/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0318 - accuracy: 0.9863
# Epoch 37: val_loss did not improve from 0.07946
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0357 - accuracy: 0.9849 - val_loss: 0.1005 - val_accuracy: 0.9492
# Epoch 38/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0181 - accuracy: 0.9941
# Epoch 38: val_loss did not improve from 0.07946
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0214 - accuracy: 0.9925 - val_loss: 0.0963 - val_accuracy: 0.9492
# Epoch 39/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0360 - accuracy: 0.9844
# Epoch 39: val_loss did not improve from 0.07946
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0286 - accuracy: 0.9903 - val_loss: 0.1002 - val_accuracy: 0.9492
# Epoch 40/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0259 - accuracy: 0.9902
# Epoch 40: val_loss did not improve from 0.07946
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0258 - accuracy: 0.9903 - val_loss: 0.0986 - val_accuracy: 0.9407
# Epoch 41/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0178 - accuracy: 0.9961
# Epoch 41: val_loss did not improve from 0.07946
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0202 - accuracy: 0.9946 - val_loss: 0.1083 - val_accuracy: 0.9407
# Epoch 42/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0192 - accuracy: 0.9941
# Epoch 42: val_loss improved from 0.07946 to 0.05716, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0270 - accuracy: 0.9871 - val_loss: 0.0572 - val_accuracy: 0.9661
# Epoch 43/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0451 - accuracy: 0.9785
# Epoch 43: val_loss did not improve from 0.05716
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0345 - accuracy: 0.9849 - val_loss: 0.1507 - val_accuracy: 0.9407
# Epoch 44/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0217 - accuracy: 0.9902
# Epoch 44: val_loss improved from 0.05716 to 0.05583, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 89ms/step - loss: 0.0394 - accuracy: 0.9849 - val_loss: 0.0558 - val_accuracy: 0.9831
# Epoch 45/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0394 - accuracy: 0.9844
# Epoch 45: val_loss did not improve from 0.05583
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0580 - accuracy: 0.9806 - val_loss: 0.0880 - val_accuracy: 0.9407
# Epoch 46/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0143 - accuracy: 0.9961
# Epoch 46: val_loss did not improve from 0.05583
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0404 - accuracy: 0.9882 - val_loss: 0.1265 - val_accuracy: 0.9407
# Epoch 47/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0355 - accuracy: 0.9863
# Epoch 47: val_loss improved from 0.05583 to 0.05383, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0344 - accuracy: 0.9882 - val_loss: 0.0538 - val_accuracy: 0.9915
# Epoch 48/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0573 - accuracy: 0.9766
# Epoch 48: val_loss did not improve from 0.05383
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0412 - accuracy: 0.9849 - val_loss: 0.1103 - val_accuracy: 0.9407
# Epoch 49/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0213 - accuracy: 0.9922
# Epoch 49: val_loss did not improve from 0.05383
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0280 - accuracy: 0.9903 - val_loss: 0.0953 - val_accuracy: 0.9407
# Epoch 50/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0160 - accuracy: 0.9941
# Epoch 50: val_loss improved from 0.05383 to 0.04832, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0221 - accuracy: 0.9892 - val_loss: 0.0483 - val_accuracy: 0.9915
# Epoch 51/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0250 - accuracy: 0.9922
# Epoch 51: val_loss did not improve from 0.04832
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0315 - accuracy: 0.9882 - val_loss: 0.0665 - val_accuracy: 0.9661
# Epoch 52/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0189 - accuracy: 0.9922
# Epoch 52: val_loss did not improve from 0.04832
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0218 - accuracy: 0.9925 - val_loss: 0.1269 - val_accuracy: 0.9492
# Epoch 53/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0484 - accuracy: 0.9805
# Epoch 53: val_loss improved from 0.04832 to 0.04557, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0380 - accuracy: 0.9849 - val_loss: 0.0456 - val_accuracy: 0.9831
# Epoch 54/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0269 - accuracy: 0.9824
# Epoch 54: val_loss did not improve from 0.04557
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0195 - accuracy: 0.9903 - val_loss: 0.0462 - val_accuracy: 0.9915
# Epoch 55/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0278 - accuracy: 0.9883
# Epoch 55: val_loss did not improve from 0.04557
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0218 - accuracy: 0.9914 - val_loss: 0.0701 - val_accuracy: 0.9576
# Epoch 56/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0167 - accuracy: 0.9941
# Epoch 56: val_loss did not improve from 0.04557
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0207 - accuracy: 0.9925 - val_loss: 0.0934 - val_accuracy: 0.9407
# Epoch 57/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0235 - accuracy: 0.9902
# Epoch 57: val_loss did not improve from 0.04557
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0178 - accuracy: 0.9935 - val_loss: 0.0501 - val_accuracy: 0.9746
# Epoch 58/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0095 - accuracy: 0.9961
# Epoch 58: val_loss did not improve from 0.04557
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0208 - accuracy: 0.9925 - val_loss: 0.0504 - val_accuracy: 0.9746
# Epoch 59/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0183 - accuracy: 0.9961
# Epoch 59: val_loss did not improve from 0.04557
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0159 - accuracy: 0.9968 - val_loss: 0.0843 - val_accuracy: 0.9492
# Epoch 60/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0151 - accuracy: 0.9961
# Epoch 60: val_loss did not improve from 0.04557
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0138 - accuracy: 0.9968 - val_loss: 0.0707 - val_accuracy: 0.9661
# Epoch 61/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0154 - accuracy: 0.9961
# Epoch 61: val_loss did not improve from 0.04557
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0129 - accuracy: 0.9978 - val_loss: 0.0460 - val_accuracy: 0.9746
# Epoch 62/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0199 - accuracy: 0.9941
# Epoch 62: val_loss did not improve from 0.04557
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0207 - accuracy: 0.9946 - val_loss: 0.0540 - val_accuracy: 0.9746
# Epoch 63/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0196 - accuracy: 0.9941
# Epoch 63: val_loss did not improve from 0.04557
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0182 - accuracy: 0.9946 - val_loss: 0.0882 - val_accuracy: 0.9492
# Epoch 64/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0224 - accuracy: 0.9941
# Epoch 64: val_loss did not improve from 0.04557
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0196 - accuracy: 0.9957 - val_loss: 0.0520 - val_accuracy: 0.9661
# Epoch 65/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0138 - accuracy: 0.9961
# Epoch 65: val_loss improved from 0.04557 to 0.04452, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0180 - accuracy: 0.9925 - val_loss: 0.0445 - val_accuracy: 0.9746
# Epoch 66/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0088 - accuracy: 0.9980
# Epoch 66: val_loss did not improve from 0.04452
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0078 - accuracy: 0.9989 - val_loss: 0.0713 - val_accuracy: 0.9661
# Epoch 67/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0084 - accuracy: 0.9980
# Epoch 67: val_loss did not improve from 0.04452
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0094 - accuracy: 0.9968 - val_loss: 0.0627 - val_accuracy: 0.9576
# Epoch 68/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 68: val_loss improved from 0.04452 to 0.04261, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 0.9831
# Epoch 69/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0086 - accuracy: 0.9980
# Epoch 69: val_loss did not improve from 0.04261
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.0575 - val_accuracy: 0.9661
# Epoch 70/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0173 - accuracy: 0.9902
# Epoch 70: val_loss did not improve from 0.04261
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0128 - accuracy: 0.9946 - val_loss: 0.1007 - val_accuracy: 0.9492
# Epoch 71/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0117 - accuracy: 0.9961
# Epoch 71: val_loss did not improve from 0.04261
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0119 - accuracy: 0.9957 - val_loss: 0.0668 - val_accuracy: 0.9492
# Epoch 72/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0124 - accuracy: 0.9961
# Epoch 72: val_loss did not improve from 0.04261
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0125 - accuracy: 0.9968 - val_loss: 0.0444 - val_accuracy: 0.9831
# Epoch 73/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0159 - accuracy: 0.9922
# Epoch 73: val_loss did not improve from 0.04261
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0118 - accuracy: 0.9957 - val_loss: 0.1206 - val_accuracy: 0.9492
# Epoch 74/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0081 - accuracy: 0.9980
# Epoch 74: val_loss did not improve from 0.04261
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0099 - accuracy: 0.9978 - val_loss: 0.1191 - val_accuracy: 0.9576
# Epoch 75/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0099 - accuracy: 0.9961
# Epoch 75: val_loss improved from 0.04261 to 0.03796, saving model to C:\Users\taemi\capstone\best_weight_model\siren_mfcc.h5
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0083 - accuracy: 0.9978 - val_loss: 0.0380 - val_accuracy: 0.9831
# Epoch 76/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0152 - accuracy: 0.9961
# Epoch 76: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0092 - accuracy: 0.9978 - val_loss: 0.0405 - val_accuracy: 0.9746
# Epoch 77/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0061 - accuracy: 0.9980
# Epoch 77: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0059 - accuracy: 0.9989 - val_loss: 0.0717 - val_accuracy: 0.9661
# Epoch 78/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0072 - accuracy: 0.9961
# Epoch 78: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0079 - accuracy: 0.9957 - val_loss: 0.0637 - val_accuracy: 0.9661
# Epoch 79/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0070 - accuracy: 0.9980
# Epoch 79: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.0400 - val_accuracy: 0.9831
# Epoch 80/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0064 - accuracy: 0.9961
# Epoch 80: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0087 - accuracy: 0.9968 - val_loss: 0.0514 - val_accuracy: 0.9746
# Epoch 81/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0062 - accuracy: 0.9980
# Epoch 81: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0090 - accuracy: 0.9957 - val_loss: 0.0721 - val_accuracy: 0.9661
# Epoch 82/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0064 - accuracy: 0.9980
# Epoch 82: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.0622 - val_accuracy: 0.9746
# Epoch 83/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0056 - accuracy: 0.9980
# Epoch 83: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0056 - accuracy: 0.9978 - val_loss: 0.0680 - val_accuracy: 0.9746
# Epoch 84/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 84: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0993 - val_accuracy: 0.9492
# Epoch 85/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0072 - accuracy: 0.9961
# Epoch 85: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0064 - accuracy: 0.9968 - val_loss: 0.0763 - val_accuracy: 0.9746
# Epoch 86/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 86: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0607 - val_accuracy: 0.9746
# Epoch 87/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 87: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0058 - accuracy: 0.9968 - val_loss: 0.0541 - val_accuracy: 0.9831
# Epoch 88/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0037 - accuracy: 0.9980
# Epoch 88: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.0722 - val_accuracy: 0.9661
# Epoch 89/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 89: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 0.9746
# Epoch 90/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 90: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.0689 - val_accuracy: 0.9661
# Epoch 91/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0030 - accuracy: 0.9980
# Epoch 91: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0032 - accuracy: 0.9978 - val_loss: 0.0498 - val_accuracy: 0.9746
# Epoch 92/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 92: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.0593 - val_accuracy: 0.9746
# Epoch 93/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 93: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0036 - accuracy: 0.9978 - val_loss: 0.0848 - val_accuracy: 0.9576
# Epoch 94/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 94: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.0693 - val_accuracy: 0.9661
# Epoch 95/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 95: val_loss did not improve from 0.03796
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0054 - accuracy: 0.9978 - val_loss: 0.0651 - val_accuracy: 0.9746
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0709 - accuracy: 0.9769
# Pre-training accuracy: 97.6923%

# %%
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
model = load_model("C:\\Users\\taemi\\capstone\\best_weight_model\\siren_mfcc.h5")
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", round(score[1]*100, 5), "%")
score = model.evaluate(x_val, y_val, verbose=0)
print("Validation Accuracy: ", round(score[1]*100, 5), "%")
score = model.evaluate(x_test, y_test, verbose=0)
print("Test Accuracy: ", round(score[1]*100, 5), "%")

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))

plt.figure(1)
plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure(2)
plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
# Out:
# Training Accuracy:  99.67707 %
# Validation Accuracy:  98.30508 %
# Test Accuracy:  98.46154 %

# %%
def print_prediction(file_name):
    prediction_feature = mfcc_extraction(file_name) 
    prediction_feature = prediction_feature.reshape(1, num_rows, num_columns, num_channels)
    
    y_prob = model.predict(prediction_feature)
    predicted_vector = y_prob.argmax(axis=-1)
    
    predicted_class = le.inverse_transform(predicted_vector) 
    print("The predicted class is:", predicted_class[0], '\n')


    predicted_proba_vector = model.predict(prediction_feature) 
    predicted_proba = predicted_proba_vector[0]
    for i in range(len(predicted_proba)): 
        category = le.inverse_transform(np.array([i]))
        print(category[0], "\t\t : ", format(predicted_proba[i], '.32f') )

# %%
def predict_prob(number):
  return [number[0],1-number[0]]

# %%
filename = 'C:\\Users\\taemi\\Documents\\소리 녹음\\fire.wav'
print_prediction(filename)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# The predicted class is: fireAlarm
#
# [2]
# 1/1 [==============================] - 0s 14ms/step
# burglarAlarm 		 :  0.00005965980381006374955177307129
# emergencyAlarm 		 :  0.00003033742905245162546634674072
# fireAlarm 		 :  0.99919193983078002929687500000000
# other 		 :  0.00071798393037170171737670898438

# %%
#휴대폰 진동소리, 문여닫는소리, 초인종소리2개, 노크소리가 일단 잘안됌 12중 5개가 잘 안된다고?
