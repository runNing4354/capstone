# %%
import librosa 
import numpy as np
import pandas as pd
import os

max = 0

def mfcc_extraction(file_name):
   
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        
        if len(audio)/sample_rate > 2:
            audio = audio[ : sample_rate*2]
        
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccsscaled = np.mean(mfccs.T,axis=0)
        global max
        if mfccs.shape[1] > max:
            max = mfccs.shape[1]

    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
     
    return mfccsscaled

# %%
# 데이터셋 path 지정
fulldatasetpath = "C:\\Users\\taemi\\capstone\\data\\1_default\\sounddata"
metadata = pd.read_csv("C:\\Users\\taemi\\capstone\\data\\1_default\\metadata_2.csv")

features = []

    
# 각 소리에 대해 feature를 추출
for index, row in metadata.iterrows():
    
    filename = os.path.join(os.path.abspath(fulldatasetpath)+'/'+str(row["filename"]))
    classname = row["class"]
    data = mfcc_extraction(filename)
    
    features.append([data, classname])
    

featuresdf = pd.DataFrame(features, columns=['feature','class'])

print('Finished feature extraction from ', len(featuresdf), ' files') 
print('Max :',max)
# Out:
# C:\Users\taemi\anaconda3\envs\py38\lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# Finished feature extraction from  2978  files
# Max : 87

# %%
import pandas as pd
from collections import Counter
from matplotlib import pyplot

#클래스별 데이터 갯수 표로 표시
data = featuresdf.values
y = data[:, -1]

def count_and_plot(y): 
    counter = Counter(y)
    for k,v in counter.items():
        print('Class=%s, n=%d (%.3f%%)' % (k, v, v / len(y) * 100))
    pyplot.bar(counter.keys(), counter.values(), width=0.3)
    pyplot.xticks(np.arange(0,8), labels=counter.keys(), rotation=90)
    pyplot.show()
    
    return v

data = featuresdf.values
y = data[:, -1]

count_and_plot(y)
# Out:
# Class=babycry, n=400 (13.432%)
# Class=glassbreak, n=400 (13.432%)
# Class=meow, n=320 (10.745%)
# Class=carhorn, n=400 (13.432%)
# Class=dogbark, n=400 (13.432%)
# Class=siren, n=400 (13.432%)
# Class=knock, n=300 (10.074%)
# Class=scream, n=358 (12.021%)
# 358

# %%
# extract feature 함수 재정의
import numpy as np
import librosa.display
max_pad_len = 87
test_num = 0

def mfcc_extraction(file_name):
    try:
        audio, sample_rate = librosa.load(file_name, res_type = 'kaiser_fast')
        
        if len(audio)/sample_rate > 2:
            audio = audio[ : sample_rate*2]
            
        mfccs = librosa.feature.mfcc(y=audio, sr = sample_rate, n_mfcc = 40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width = ((0, 0), (0, pad_width)), mode = 'constant')
    
    except Exception as e:
        print("Error 발생: ", file_name)
        return None
    
    return mfccs

# %%
import os

# 데이터셋 path 지정
fulldatasetpath = "C:\\Users\\taemi\\capstone\\data\\1_default\\sounddata"

metadata = pd.read_csv("C:\\Users\\taemi\\capstone\\data\\1_default\\metadata_2.csv")

features = []

# 각 소리에 대해 feature를 추출
for index, row in metadata.iterrows():
    
    file_name = os.path.join(os.path.abspath(fulldatasetpath)+'/'+str(row["filename"]))
    classname = row['class']
    data = mfcc_extraction(file_name)
        
        
    features.append([data, classname])
   
 


featuresdf = pd.DataFrame(features, columns=['feature','class'])
print('Finished feature extraction from ', len(featuresdf), ' files')
# Out:
# C:\Users\taemi\anaconda3\envs\py38\lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# Finished feature extraction from  2978  files

# %%
featuresdf['feature'][0]
# Out:
# array([[-5.47529663e+02, -5.47370117e+02, -5.46013977e+02, ...,
#         -1.99408646e+02, -1.78832001e+02, -2.01808121e+02],
#        [ 5.56641293e+00,  5.79727650e+00,  7.70203114e+00, ...,
#          4.30521355e+01,  9.54146290e+00, -7.92288494e+00],
#        [ 5.52671242e+00,  5.77303457e+00,  7.63944340e+00, ...,
#         -2.16014137e+01, -1.37781105e+01, -5.99817848e+00],
#        ...,
#        [ 1.83460355e-01,  5.67780316e-01,  2.01452583e-01, ...,
#         -3.50399399e+00, -8.20554614e-01,  4.80388165e+00],
#        [ 1.05121106e-01,  4.95549917e-01,  1.22725956e-01, ...,
#         -7.66373634e-01, -1.04912162e+00,  3.28306031e+00],
#        [ 3.89083661e-02,  4.34112251e-01,  4.16725688e-02, ...,
#         -2.97019243e+00, -9.44101155e-01,  2.28403544e+00]], dtype=float32)

# %%
import librosa.display
from matplotlib import pyplot as plt

plt.figure()
librosa.display.specshow(featuresdf['feature'][300], sr = 22050, x_axis='time')
plt.colorbar()
plt.title(featuresdf['class'][300])
# Out:
# Text(0.5, 1.0, 'knock')

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import numpy as np
import pandas as pd


# Pandas로 저장된 각 열을 np.array로 반환
# X는 MFCC의 데이터
X = np.array(featuresdf.feature.tolist())
# Y는 그 데이터의 Label이 저장됨
y = np.array(featuresdf['class'].tolist())

# Tensorflow에 Label이 사용될 수 있도록 Label을 숫자로 인코딩 해준다.
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y))

# Test 데이터와 Train 데이터로 2:8로 나눈다.(셔플값이 디폴트이기 때문에 굳이 설정안해도 됨)
x_train, x_val, y_train, y_val = train_test_split(X, yy, test_size=0.1, random_state=1)
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.12222, random_state=1)

# %%
num_rows = 40
num_columns = 87
num_channels = 1

print("train data shape")
print(x_train.shape)
print(x_test.shape)
print(x_val.shape)

x_train = x_train.reshape(x_train.shape[0], num_rows, num_columns, num_channels)
x_test = x_test.reshape(x_test.shape[0], num_rows, num_columns, num_channels)
x_val = x_val.reshape(x_val.shape[0], num_rows, num_columns, num_channels)

print("\ntrain data reshape 결과")
print(x_train.shape)
print(x_test.shape)
print(x_val.shape)
# Out:
# train data shape
# (2352, 40, 87)
# (328, 40, 87)
# (298, 40, 87)
#
# train data reshape 결과
# (2352, 40, 87, 1)
# (328, 40, 87, 1)
# (298, 40, 87, 1)

# %%
# Out:
# 12

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D,Convolution2D, MaxPooling2D, GlobalAveragePooling2D, Dropout,LeakyReLU, BatchNormalization
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.utils import np_utils
from sklearn import metrics

num_labels = yy.shape[1]
filter_size = 2

# HyperParameter
EPOCHS = 1000
BATCH_SIZE = 512
MODEL_SAVE = "C:\\Users\\taemi\\capstone\\best_weight_model"
if not os.path.exists(MODEL_SAVE):
    os.mkdir(MODEL_SAVE)
    
checkpoint = ModelCheckpoint(filepath="{}/default_mfcc.h5".format(MODEL_SAVE), monitor="val_loss",
                             verbose=1, save_best_only=True)

ealrystopping = EarlyStopping(monitor="val_loss", patience=20)

#CNN모델 구현
model = Sequential([
    Conv2D(16, 4, padding="same", input_shape=(num_rows, num_columns, num_channels), activation=LeakyReLU(0.1)),
    MaxPooling2D(),
    Dropout(0.2),
    Conv2D(32, 1, activation="relu"),
    Conv2D(64, 2, activation="relu"),
    MaxPooling2D(),
    Dropout(0.2),
    Conv2D(128, 4, activation=LeakyReLU(0.1)),
    MaxPooling2D(),
    Dropout(0.2),
    GlobalAveragePooling2D(),
    Dense(512, activation="relu"),
    Dropout(0.2),
    Dense(1024, activation="relu"),
    Dropout(0.2),
    Dense(num_labels, activation="softmax")])



#컴파일
model.compile(loss = 'categorical_crossentropy', metrics = ['accuracy'], optimizer = 'adam')  
model.summary()
history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(x_val, y_val),
          callbacks=[checkpoint, ealrystopping], verbose=1)

score = model.evaluate(x_test, y_test, verbose = 1)
accuracy = 100 * score[1]

print('Pre-training accuracy: %.4f%%' % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 40, 87, 16)        272
#
#  max_pooling2d (MaxPooling2D  (None, 20, 43, 16)       0
#  )
#
#  dropout (Dropout)           (None, 20, 43, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 20, 43, 32)        544
#
#  conv2d_2 (Conv2D)           (None, 19, 42, 64)        8256
#
#  max_pooling2d_1 (MaxPooling  (None, 9, 21, 64)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 9, 21, 64)         0
#
#  conv2d_3 (Conv2D)           (None, 6, 18, 128)        131200
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 9, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 3, 9, 128)         0
#
#  global_average_pooling2d (G  (None, 128)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               66048
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1024)              525312
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 8)                 8200
#
# =================================================================
# Total params: 739,832
# Trainable params: 739,832
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 5/5 [==============================] - ETA: 0s - loss: 4.1912 - accuracy: 0.1344
# Epoch 1: val_loss improved from inf to 1.94398, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 4s 168ms/step - loss: 4.1912 - accuracy: 0.1344 - val_loss: 1.9440 - val_accuracy: 0.2383
# Epoch 2/1000
# 5/5 [==============================] - ETA: 0s - loss: 2.0217 - accuracy: 0.2130
# Epoch 2: val_loss did not improve from 1.94398
# 5/5 [==============================] - 0s 38ms/step - loss: 2.0217 - accuracy: 0.2130 - val_loss: 1.9777 - val_accuracy: 0.2718
# Epoch 3/1000
# 5/5 [==============================] - ETA: 0s - loss: 1.8717 - accuracy: 0.2700
# Epoch 3: val_loss improved from 1.94398 to 1.81218, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 51ms/step - loss: 1.8717 - accuracy: 0.2700 - val_loss: 1.8122 - val_accuracy: 0.2752
# Epoch 4/1000
# 5/5 [==============================] - ETA: 0s - loss: 1.7133 - accuracy: 0.3516
# Epoch 4: val_loss improved from 1.81218 to 1.70974, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 46ms/step - loss: 1.7133 - accuracy: 0.3516 - val_loss: 1.7097 - val_accuracy: 0.4060
# Epoch 5/1000
# 5/5 [==============================] - ETA: 0s - loss: 1.5805 - accuracy: 0.4094
# Epoch 5: val_loss improved from 1.70974 to 1.56389, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 46ms/step - loss: 1.5805 - accuracy: 0.4094 - val_loss: 1.5639 - val_accuracy: 0.4094
# Epoch 6/1000
# 5/5 [==============================] - ETA: 0s - loss: 1.4144 - accuracy: 0.4966
# Epoch 6: val_loss improved from 1.56389 to 1.38149, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 48ms/step - loss: 1.4144 - accuracy: 0.4966 - val_loss: 1.3815 - val_accuracy: 0.5436
# Epoch 7/1000
# 5/5 [==============================] - ETA: 0s - loss: 1.2032 - accuracy: 0.5736
# Epoch 7: val_loss improved from 1.38149 to 1.22008, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 47ms/step - loss: 1.2032 - accuracy: 0.5736 - val_loss: 1.2201 - val_accuracy: 0.6376
# Epoch 8/1000
# 5/5 [==============================] - ETA: 0s - loss: 1.0132 - accuracy: 0.6539
# Epoch 8: val_loss improved from 1.22008 to 1.06432, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 46ms/step - loss: 1.0132 - accuracy: 0.6539 - val_loss: 1.0643 - val_accuracy: 0.6812
# Epoch 9/1000
# 3/5 [=================>............] - ETA: 0s - loss: 0.8872 - accuracy: 0.6940
# Epoch 9: val_loss improved from 1.06432 to 0.95657, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 43ms/step - loss: 0.8556 - accuracy: 0.7041 - val_loss: 0.9566 - val_accuracy: 0.6980
# Epoch 10/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.7583 - accuracy: 0.7406
# Epoch 10: val_loss improved from 0.95657 to 0.87042, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 52ms/step - loss: 0.7583 - accuracy: 0.7406 - val_loss: 0.8704 - val_accuracy: 0.6980
# Epoch 11/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.6731 - accuracy: 0.7615
# Epoch 11: val_loss improved from 0.87042 to 0.74369, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 47ms/step - loss: 0.6731 - accuracy: 0.7615 - val_loss: 0.7437 - val_accuracy: 0.7584
# Epoch 12/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.6076 - accuracy: 0.7883
# Epoch 12: val_loss improved from 0.74369 to 0.61520, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 46ms/step - loss: 0.6076 - accuracy: 0.7883 - val_loss: 0.6152 - val_accuracy: 0.7852
# Epoch 13/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.5472 - accuracy: 0.8095
# Epoch 13: val_loss improved from 0.61520 to 0.56678, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 45ms/step - loss: 0.5472 - accuracy: 0.8095 - val_loss: 0.5668 - val_accuracy: 0.8087
# Epoch 14/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.5163 - accuracy: 0.8168
# Epoch 14: val_loss did not improve from 0.56678
# 5/5 [==============================] - 0s 36ms/step - loss: 0.5163 - accuracy: 0.8168 - val_loss: 0.6005 - val_accuracy: 0.8020
# Epoch 15/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.4715 - accuracy: 0.8410
# Epoch 15: val_loss did not improve from 0.56678
# 5/5 [==============================] - 0s 45ms/step - loss: 0.4715 - accuracy: 0.8410 - val_loss: 0.5762 - val_accuracy: 0.8188
# Epoch 16/1000
# 3/5 [=================>............] - ETA: 0s - loss: 0.4637 - accuracy: 0.8307
# Epoch 16: val_loss improved from 0.56678 to 0.43536, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 48ms/step - loss: 0.4641 - accuracy: 0.8367 - val_loss: 0.4354 - val_accuracy: 0.8624
# Epoch 17/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.4138 - accuracy: 0.8584
# Epoch 17: val_loss improved from 0.43536 to 0.42951, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 46ms/step - loss: 0.4138 - accuracy: 0.8584 - val_loss: 0.4295 - val_accuracy: 0.8490
# Epoch 18/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.3996 - accuracy: 0.8622
# Epoch 18: val_loss did not improve from 0.42951
# 5/5 [==============================] - 0s 37ms/step - loss: 0.3996 - accuracy: 0.8622 - val_loss: 0.4715 - val_accuracy: 0.8255
# Epoch 19/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.3642 - accuracy: 0.8771
# Epoch 19: val_loss did not improve from 0.42951
# 5/5 [==============================] - 0s 39ms/step - loss: 0.3642 - accuracy: 0.8771 - val_loss: 0.4308 - val_accuracy: 0.8356
# Epoch 20/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.3600 - accuracy: 0.8780
# Epoch 20: val_loss improved from 0.42951 to 0.34735, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 52ms/step - loss: 0.3600 - accuracy: 0.8780 - val_loss: 0.3474 - val_accuracy: 0.8893
# Epoch 21/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.3374 - accuracy: 0.8822
# Epoch 21: val_loss improved from 0.34735 to 0.32007, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 48ms/step - loss: 0.3374 - accuracy: 0.8822 - val_loss: 0.3201 - val_accuracy: 0.9027
# Epoch 22/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.3031 - accuracy: 0.8967
# Epoch 22: val_loss did not improve from 0.32007
# 5/5 [==============================] - 0s 37ms/step - loss: 0.3031 - accuracy: 0.8967 - val_loss: 0.3388 - val_accuracy: 0.8859
# Epoch 23/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.2876 - accuracy: 0.9014
# Epoch 23: val_loss did not improve from 0.32007
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2876 - accuracy: 0.9014 - val_loss: 0.3336 - val_accuracy: 0.8826
# Epoch 24/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.2707 - accuracy: 0.9082
# Epoch 24: val_loss improved from 0.32007 to 0.28641, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 53ms/step - loss: 0.2707 - accuracy: 0.9082 - val_loss: 0.2864 - val_accuracy: 0.8993
# Epoch 25/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.2588 - accuracy: 0.9141
# Epoch 25: val_loss improved from 0.28641 to 0.25048, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2588 - accuracy: 0.9141 - val_loss: 0.2505 - val_accuracy: 0.9195
# Epoch 26/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.2352 - accuracy: 0.9171
# Epoch 26: val_loss did not improve from 0.25048
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2352 - accuracy: 0.9171 - val_loss: 0.2710 - val_accuracy: 0.9195
# Epoch 27/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.2335 - accuracy: 0.9213
# Epoch 27: val_loss did not improve from 0.25048
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2335 - accuracy: 0.9213 - val_loss: 0.3061 - val_accuracy: 0.9128
# Epoch 28/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.2180 - accuracy: 0.9239
# Epoch 28: val_loss did not improve from 0.25048
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2180 - accuracy: 0.9239 - val_loss: 0.2542 - val_accuracy: 0.9228
# Epoch 29/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.2156 - accuracy: 0.9294
# Epoch 29: val_loss improved from 0.25048 to 0.24323, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2156 - accuracy: 0.9294 - val_loss: 0.2432 - val_accuracy: 0.9329
# Epoch 30/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1879 - accuracy: 0.9332
# Epoch 30: val_loss improved from 0.24323 to 0.23949, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1879 - accuracy: 0.9332 - val_loss: 0.2395 - val_accuracy: 0.9094
# Epoch 31/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1975 - accuracy: 0.9354
# Epoch 31: val_loss did not improve from 0.23949
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1975 - accuracy: 0.9354 - val_loss: 0.2546 - val_accuracy: 0.9128
# Epoch 32/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1815 - accuracy: 0.9379
# Epoch 32: val_loss did not improve from 0.23949
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1815 - accuracy: 0.9379 - val_loss: 0.2635 - val_accuracy: 0.9128
# Epoch 33/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1707 - accuracy: 0.9388
# Epoch 33: val_loss improved from 0.23949 to 0.21522, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1707 - accuracy: 0.9388 - val_loss: 0.2152 - val_accuracy: 0.9430
# Epoch 34/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1720 - accuracy: 0.9349
# Epoch 34: val_loss improved from 0.21522 to 0.19418, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1720 - accuracy: 0.9349 - val_loss: 0.1942 - val_accuracy: 0.9497
# Epoch 35/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1698 - accuracy: 0.9426
# Epoch 35: val_loss did not improve from 0.19418
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1698 - accuracy: 0.9426 - val_loss: 0.1968 - val_accuracy: 0.9430
# Epoch 36/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9490
# Epoch 36: val_loss did not improve from 0.19418
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1530 - accuracy: 0.9490 - val_loss: 0.2101 - val_accuracy: 0.9396
# Epoch 37/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1329 - accuracy: 0.9549
# Epoch 37: val_loss did not improve from 0.19418
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1329 - accuracy: 0.9549 - val_loss: 0.1985 - val_accuracy: 0.9362
# Epoch 38/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1286 - accuracy: 0.9562
# Epoch 38: val_loss improved from 0.19418 to 0.14974, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1286 - accuracy: 0.9562 - val_loss: 0.1497 - val_accuracy: 0.9597
# Epoch 39/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1221 - accuracy: 0.9613
# Epoch 39: val_loss did not improve from 0.14974
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1221 - accuracy: 0.9613 - val_loss: 0.1902 - val_accuracy: 0.9497
# Epoch 40/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1151 - accuracy: 0.9575
# Epoch 40: val_loss did not improve from 0.14974
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1151 - accuracy: 0.9575 - val_loss: 0.1741 - val_accuracy: 0.9362
# Epoch 41/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1083 - accuracy: 0.9639
# Epoch 41: val_loss did not improve from 0.14974
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1083 - accuracy: 0.9639 - val_loss: 0.1712 - val_accuracy: 0.9396
# Epoch 42/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1063 - accuracy: 0.9647
# Epoch 42: val_loss did not improve from 0.14974
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1063 - accuracy: 0.9647 - val_loss: 0.1572 - val_accuracy: 0.9530
# Epoch 43/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1078 - accuracy: 0.9613
# Epoch 43: val_loss did not improve from 0.14974
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1078 - accuracy: 0.9613 - val_loss: 0.2459 - val_accuracy: 0.9195
# Epoch 44/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1224 - accuracy: 0.9562
# Epoch 44: val_loss did not improve from 0.14974
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1224 - accuracy: 0.9562 - val_loss: 0.1801 - val_accuracy: 0.9497
# Epoch 45/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1068 - accuracy: 0.9613
# Epoch 45: val_loss did not improve from 0.14974
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1068 - accuracy: 0.9613 - val_loss: 0.1565 - val_accuracy: 0.9497
# Epoch 46/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1013 - accuracy: 0.9605
# Epoch 46: val_loss did not improve from 0.14974
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1013 - accuracy: 0.9605 - val_loss: 0.1540 - val_accuracy: 0.9597
# Epoch 47/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.1026 - accuracy: 0.9592
# Epoch 47: val_loss improved from 0.14974 to 0.13569, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 58ms/step - loss: 0.1026 - accuracy: 0.9592 - val_loss: 0.1357 - val_accuracy: 0.9597
# Epoch 48/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0881 - accuracy: 0.9732
# Epoch 48: val_loss did not improve from 0.13569
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0881 - accuracy: 0.9732 - val_loss: 0.2222 - val_accuracy: 0.9329
# Epoch 49/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0923 - accuracy: 0.9681
# Epoch 49: val_loss did not improve from 0.13569
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0923 - accuracy: 0.9681 - val_loss: 0.1504 - val_accuracy: 0.9631
# Epoch 50/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0813 - accuracy: 0.9719
# Epoch 50: val_loss did not improve from 0.13569
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0813 - accuracy: 0.9719 - val_loss: 0.1724 - val_accuracy: 0.9497
# Epoch 51/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0962 - accuracy: 0.9664
# Epoch 51: val_loss improved from 0.13569 to 0.11864, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0962 - accuracy: 0.9664 - val_loss: 0.1186 - val_accuracy: 0.9698
# Epoch 52/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0869 - accuracy: 0.9685
# Epoch 52: val_loss did not improve from 0.11864
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0869 - accuracy: 0.9685 - val_loss: 0.1949 - val_accuracy: 0.9497
# Epoch 53/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0769 - accuracy: 0.9719
# Epoch 53: val_loss did not improve from 0.11864
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0769 - accuracy: 0.9719 - val_loss: 0.1403 - val_accuracy: 0.9530
# Epoch 54/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0801 - accuracy: 0.9707
# Epoch 54: val_loss did not improve from 0.11864
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0801 - accuracy: 0.9707 - val_loss: 0.1276 - val_accuracy: 0.9597
# Epoch 55/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0654 - accuracy: 0.9792
# Epoch 55: val_loss did not improve from 0.11864
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0654 - accuracy: 0.9792 - val_loss: 0.1530 - val_accuracy: 0.9564
# Epoch 56/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0812 - accuracy: 0.9664
# Epoch 56: val_loss did not improve from 0.11864
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0812 - accuracy: 0.9664 - val_loss: 0.1398 - val_accuracy: 0.9430
# Epoch 57/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9702
# Epoch 57: val_loss did not improve from 0.11864
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0862 - accuracy: 0.9702 - val_loss: 0.1927 - val_accuracy: 0.9396
# Epoch 58/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0861 - accuracy: 0.9707
# Epoch 58: val_loss did not improve from 0.11864
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0861 - accuracy: 0.9707 - val_loss: 0.1522 - val_accuracy: 0.9564
# Epoch 59/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0736 - accuracy: 0.9758
# Epoch 59: val_loss did not improve from 0.11864
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0736 - accuracy: 0.9758 - val_loss: 0.1623 - val_accuracy: 0.9396
# Epoch 60/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9787
# Epoch 60: val_loss did not improve from 0.11864
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0613 - accuracy: 0.9787 - val_loss: 0.1371 - val_accuracy: 0.9664
# Epoch 61/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9830
# Epoch 61: val_loss did not improve from 0.11864
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0521 - accuracy: 0.9830 - val_loss: 0.1567 - val_accuracy: 0.9463
# Epoch 62/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.9830
# Epoch 62: val_loss did not improve from 0.11864
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0517 - accuracy: 0.9830 - val_loss: 0.1228 - val_accuracy: 0.9765
# Epoch 63/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9830
# Epoch 63: val_loss did not improve from 0.11864
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0503 - accuracy: 0.9830 - val_loss: 0.1304 - val_accuracy: 0.9597
# Epoch 64/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0523 - accuracy: 0.9834
# Epoch 64: val_loss did not improve from 0.11864
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0523 - accuracy: 0.9834 - val_loss: 0.1457 - val_accuracy: 0.9664
# Epoch 65/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.9872
# Epoch 65: val_loss improved from 0.11864 to 0.11056, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0464 - accuracy: 0.9872 - val_loss: 0.1106 - val_accuracy: 0.9564
# Epoch 66/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0582 - accuracy: 0.9783
# Epoch 66: val_loss did not improve from 0.11056
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0582 - accuracy: 0.9783 - val_loss: 0.1496 - val_accuracy: 0.9664
# Epoch 67/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9796
# Epoch 67: val_loss did not improve from 0.11056
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0616 - accuracy: 0.9796 - val_loss: 0.1840 - val_accuracy: 0.9430
# Epoch 68/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9787
# Epoch 68: val_loss did not improve from 0.11056
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0602 - accuracy: 0.9787 - val_loss: 0.1525 - val_accuracy: 0.9564
# Epoch 69/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0684 - accuracy: 0.9749
# Epoch 69: val_loss did not improve from 0.11056
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0684 - accuracy: 0.9749 - val_loss: 0.1253 - val_accuracy: 0.9631
# Epoch 70/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9847
# Epoch 70: val_loss did not improve from 0.11056
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0428 - accuracy: 0.9847 - val_loss: 0.1354 - val_accuracy: 0.9732
# Epoch 71/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9847
# Epoch 71: val_loss did not improve from 0.11056
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0447 - accuracy: 0.9847 - val_loss: 0.1226 - val_accuracy: 0.9664
# Epoch 72/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9889
# Epoch 72: val_loss did not improve from 0.11056
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0370 - accuracy: 0.9889 - val_loss: 0.1197 - val_accuracy: 0.9732
# Epoch 73/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9872
# Epoch 73: val_loss did not improve from 0.11056
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0350 - accuracy: 0.9872 - val_loss: 0.1217 - val_accuracy: 0.9765
# Epoch 74/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 0.9860
# Epoch 74: val_loss did not improve from 0.11056
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0374 - accuracy: 0.9860 - val_loss: 0.1422 - val_accuracy: 0.9564
# Epoch 75/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0381 - accuracy: 0.9885
# Epoch 75: val_loss improved from 0.11056 to 0.10684, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0381 - accuracy: 0.9885 - val_loss: 0.1068 - val_accuracy: 0.9765
# Epoch 76/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9911
# Epoch 76: val_loss did not improve from 0.10684
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0293 - accuracy: 0.9911 - val_loss: 0.1677 - val_accuracy: 0.9530
# Epoch 77/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0443 - accuracy: 0.9855
# Epoch 77: val_loss did not improve from 0.10684
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0443 - accuracy: 0.9855 - val_loss: 0.1105 - val_accuracy: 0.9664
# Epoch 78/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9906
# Epoch 78: val_loss did not improve from 0.10684
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0284 - accuracy: 0.9906 - val_loss: 0.1251 - val_accuracy: 0.9664
# Epoch 79/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0307 - accuracy: 0.9868
# Epoch 79: val_loss improved from 0.10684 to 0.10656, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0307 - accuracy: 0.9868 - val_loss: 0.1066 - val_accuracy: 0.9664
# Epoch 80/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0335 - accuracy: 0.9894
# Epoch 80: val_loss did not improve from 0.10656
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0335 - accuracy: 0.9894 - val_loss: 0.1441 - val_accuracy: 0.9597
# Epoch 81/1000
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0317 - accuracy: 0.9888
# Epoch 81: val_loss improved from 0.10656 to 0.10028, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0290 - accuracy: 0.9898 - val_loss: 0.1003 - val_accuracy: 0.9765
# Epoch 82/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9855
# Epoch 82: val_loss did not improve from 0.10028
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0367 - accuracy: 0.9855 - val_loss: 0.1441 - val_accuracy: 0.9597
# Epoch 83/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.9881
# Epoch 83: val_loss did not improve from 0.10028
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0324 - accuracy: 0.9881 - val_loss: 0.1011 - val_accuracy: 0.9732
# Epoch 84/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0335 - accuracy: 0.9898
# Epoch 84: val_loss did not improve from 0.10028
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0335 - accuracy: 0.9898 - val_loss: 0.1624 - val_accuracy: 0.9463
# Epoch 85/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9894
# Epoch 85: val_loss improved from 0.10028 to 0.09110, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0332 - accuracy: 0.9894 - val_loss: 0.0911 - val_accuracy: 0.9799
# Epoch 86/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9923
# Epoch 86: val_loss did not improve from 0.09110
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0245 - accuracy: 0.9923 - val_loss: 0.0920 - val_accuracy: 0.9732
# Epoch 87/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.9911
# Epoch 87: val_loss did not improve from 0.09110
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0270 - accuracy: 0.9911 - val_loss: 0.1271 - val_accuracy: 0.9698
# Epoch 88/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9877
# Epoch 88: val_loss did not improve from 0.09110
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0317 - accuracy: 0.9877 - val_loss: 0.1404 - val_accuracy: 0.9664
# Epoch 89/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.9902
# Epoch 89: val_loss did not improve from 0.09110
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0248 - accuracy: 0.9902 - val_loss: 0.1241 - val_accuracy: 0.9664
# Epoch 90/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9872
# Epoch 90: val_loss did not improve from 0.09110
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0326 - accuracy: 0.9872 - val_loss: 0.1310 - val_accuracy: 0.9698
# Epoch 91/1000
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0231 - accuracy: 0.9932
# Epoch 91: val_loss did not improve from 0.09110
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0268 - accuracy: 0.9919 - val_loss: 0.1634 - val_accuracy: 0.9597
# Epoch 92/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9821
# Epoch 92: val_loss did not improve from 0.09110
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0406 - accuracy: 0.9821 - val_loss: 0.1100 - val_accuracy: 0.9765
# Epoch 93/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9885
# Epoch 93: val_loss did not improve from 0.09110
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0332 - accuracy: 0.9885 - val_loss: 0.1552 - val_accuracy: 0.9597
# Epoch 94/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.9881
# Epoch 94: val_loss did not improve from 0.09110
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0324 - accuracy: 0.9881 - val_loss: 0.1272 - val_accuracy: 0.9698
# Epoch 95/1000
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0448 - accuracy: 0.9839
# Epoch 95: val_loss did not improve from 0.09110
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0406 - accuracy: 0.9860 - val_loss: 0.1252 - val_accuracy: 0.9698
# Epoch 96/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9826
# Epoch 96: val_loss did not improve from 0.09110
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0518 - accuracy: 0.9826 - val_loss: 0.1171 - val_accuracy: 0.9698
# Epoch 97/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9889
# Epoch 97: val_loss did not improve from 0.09110
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0309 - accuracy: 0.9889 - val_loss: 0.1677 - val_accuracy: 0.9597
# Epoch 98/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.9915
# Epoch 98: val_loss improved from 0.09110 to 0.08808, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0258 - accuracy: 0.9915 - val_loss: 0.0881 - val_accuracy: 0.9732
# Epoch 99/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9915
# Epoch 99: val_loss did not improve from 0.08808
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0259 - accuracy: 0.9915 - val_loss: 0.1343 - val_accuracy: 0.9597
# Epoch 100/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9911
# Epoch 100: val_loss did not improve from 0.08808
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0261 - accuracy: 0.9911 - val_loss: 0.1109 - val_accuracy: 0.9698
# Epoch 101/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9966
# Epoch 101: val_loss did not improve from 0.08808
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0160 - accuracy: 0.9966 - val_loss: 0.1392 - val_accuracy: 0.9631
# Epoch 102/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 0.9923
# Epoch 102: val_loss did not improve from 0.08808
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0215 - accuracy: 0.9923 - val_loss: 0.0999 - val_accuracy: 0.9799
# Epoch 103/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9928
# Epoch 103: val_loss did not improve from 0.08808
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0206 - accuracy: 0.9928 - val_loss: 0.1141 - val_accuracy: 0.9732
# Epoch 104/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9945
# Epoch 104: val_loss improved from 0.08808 to 0.08787, saving model to C:\Users\taemi\capstone\best_weight_model\default_mfcc.h5
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0201 - accuracy: 0.9945 - val_loss: 0.0879 - val_accuracy: 0.9765
# Epoch 105/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9928
# Epoch 105: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0236 - accuracy: 0.9928 - val_loss: 0.0993 - val_accuracy: 0.9698
# Epoch 106/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9911
# Epoch 106: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0236 - accuracy: 0.9911 - val_loss: 0.0952 - val_accuracy: 0.9799
# Epoch 107/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9928
# Epoch 107: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0234 - accuracy: 0.9928 - val_loss: 0.1184 - val_accuracy: 0.9732
# Epoch 108/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9911
# Epoch 108: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0275 - accuracy: 0.9911 - val_loss: 0.1507 - val_accuracy: 0.9597
# Epoch 109/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9953
# Epoch 109: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0156 - accuracy: 0.9953 - val_loss: 0.1458 - val_accuracy: 0.9631
# Epoch 110/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9932
# Epoch 110: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0192 - accuracy: 0.9932 - val_loss: 0.1083 - val_accuracy: 0.9732
# Epoch 111/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9957
# Epoch 111: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0132 - accuracy: 0.9957 - val_loss: 0.1702 - val_accuracy: 0.9497
# Epoch 112/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9906
# Epoch 112: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0229 - accuracy: 0.9906 - val_loss: 0.1007 - val_accuracy: 0.9732
# Epoch 113/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9957
# Epoch 113: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0143 - accuracy: 0.9957 - val_loss: 0.1504 - val_accuracy: 0.9698
# Epoch 114/1000
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0167 - accuracy: 0.9956
# Epoch 114: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0157 - accuracy: 0.9962 - val_loss: 0.1060 - val_accuracy: 0.9732
# Epoch 115/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9970
# Epoch 115: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0100 - accuracy: 0.9970 - val_loss: 0.0933 - val_accuracy: 0.9832
# Epoch 116/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9966
# Epoch 116: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0103 - accuracy: 0.9966 - val_loss: 0.0941 - val_accuracy: 0.9664
# Epoch 117/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9962
# Epoch 117: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0102 - accuracy: 0.9962 - val_loss: 0.1144 - val_accuracy: 0.9765
# Epoch 118/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9974
# Epoch 118: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0121 - accuracy: 0.9974 - val_loss: 0.1244 - val_accuracy: 0.9664
# Epoch 119/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9962
# Epoch 119: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0110 - accuracy: 0.9962 - val_loss: 0.1256 - val_accuracy: 0.9698
# Epoch 120/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9953
# Epoch 120: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0160 - accuracy: 0.9953 - val_loss: 0.1130 - val_accuracy: 0.9732
# Epoch 121/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 0.9945
# Epoch 121: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0166 - accuracy: 0.9945 - val_loss: 0.1393 - val_accuracy: 0.9664
# Epoch 122/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9945
# Epoch 122: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0139 - accuracy: 0.9945 - val_loss: 0.1454 - val_accuracy: 0.9765
# Epoch 123/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9953
# Epoch 123: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0112 - accuracy: 0.9953 - val_loss: 0.1415 - val_accuracy: 0.9732
# Epoch 124/1000
# 5/5 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9945
# Epoch 124: val_loss did not improve from 0.08787
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0148 - accuracy: 0.9945 - val_loss: 0.1316 - val_accuracy: 0.9664
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2547 - accuracy: 0.9543
# Pre-training accuracy: 95.4268%

# %%
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
model = load_model("C:\\Users\\taemi\\capstone\\best_weight_model\\default_mfcc.h5")
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", round(score[1]*100, 5), "%")
score = model.evaluate(x_val, y_val, verbose=0)
print("Validation Accuracy: ", round(score[1]*100, 5), "%")
score = model.evaluate(x_test, y_test, verbose=0)
print("Test Accuracy: ", round(score[1]*100, 5), "%")

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))

plt.figure(1)
plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure(2)
plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
# Out:
# Training Accuracy:  99.95748 %
# Validation Accuracy:  97.651 %
# Test Accuracy:  95.73171 %

# %%
def print_prediction(file_name):
    prediction_feature = mfcc_extraction(file_name) 
    prediction_feature = prediction_feature.reshape(1, num_rows, num_columns, num_channels)
    
    y_prob = model.predict(prediction_feature)
    predicted_vector = y_prob.argmax(axis=-1)
    
    predicted_class = le.inverse_transform(predicted_vector) 
    print("The predicted class is:", predicted_class[0], '\n') 


    predicted_proba_vector = model.predict(prediction_feature) 
    predicted_proba = predicted_proba_vector[0]
    for i in range(len(predicted_proba)): 
        category = le.inverse_transform(np.array([i]))
        print(category[0], "\t\t : ", format(predicted_proba[i], '.32f') )

# %%
def predict_prob(number):
  return [number[0],1-number[0]]

# %%
filename = 'C:\\Users\\taemi\\Documents\\소리 녹음\\glass.wav'
print_prediction(filename)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# The predicted class is: glassbreak
#
# 1/1 [==============================] - 0s 13ms/step
# babycry 		 :  0.00000001496951540502777788788080
# carhorn 		 :  0.00000000000070127248192469737731
# dogbark 		 :  0.00000000019818129082249669181692
# glassbreak 		 :  1.00000000000000000000000000000000
# knock 		 :  0.00000000077661221897784571410739
# meow 		 :  0.00000000296554891754396976466523
# scream 		 :  0.00000000789464227324288003728725
# siren 		 :  0.00000000000443222064952508709723

# %%
#휴대폰 진동소리, 문여닫는소리, 초인종소리2개, 노크소리가 일단 잘안됌 12중 5개가 잘 안된다고?
