# %%
import librosa 
import numpy as np
import pandas as pd
import os

max = 0

def mfcc_extraction(file_name):
   
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        
        if len(audio)/sample_rate > 2:
            audio = audio[ : sample_rate*2]
        
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccsscaled = np.mean(mfccs.T,axis=0)
        global max
        if mfccs.shape[1] > max:
            max = mfccs.shape[1]

    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
     
    return mfccsscaled

# %%
# 데이터셋 path 지정
fulldatasetpath = "C:\\Users\\taemi\\capstone\\data\\3_babycry\\sounddata"
metadata = pd.read_csv("C:\\Users\\taemi\\capstone\\data\\3_babycry\\metadata_2.csv")

features = []

    
# 각 소리에 대해 feature를 추출
for index, row in metadata.iterrows():
    
    filename = os.path.join(os.path.abspath(fulldatasetpath)+'/'+str(row["filename"]))
    classname = row["class"]
    data = mfcc_extraction(filename)
    
    features.append([data, classname])
    

featuresdf = pd.DataFrame(features, columns=['feature','class'])

print('Finished feature extraction from ', len(featuresdf), ' files') 
print('Max :',max)
# Out:
# C:\Users\taemi\anaconda3\envs\py38\lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# Finished feature extraction from  800  files
# Max : 87

# %%
import pandas as pd
from collections import Counter
from matplotlib import pyplot

#클래스별 데이터 갯수 표로 표시
data = featuresdf.values
y = data[:, -1]

def count_and_plot(y): 
    counter = Counter(y)
    for k,v in counter.items():
        print('Class=%s, n=%d (%.3f%%)' % (k, v, v / len(y) * 100))
    pyplot.bar(counter.keys(), counter.values(), width=0.3)
    pyplot.xticks(np.arange(0,2), labels=counter.keys(), rotation=90)
    pyplot.show()
    
    return v

data = featuresdf.values
y = data[:, -1]

count_and_plot(y)
# Out:
# Class=babycry, n=400 (50.000%)
# Class=other, n=400 (50.000%)
# 400

# %%
# extract feature 함수 재정의
import numpy as np
import librosa.display
max_pad_len = 87
test_num = 0

def mfcc_extraction(file_name):
    try:
        audio, sample_rate = librosa.load(file_name, res_type = 'kaiser_fast')
        
        if len(audio)/sample_rate > 2:
            audio = audio[ : sample_rate*2]
            
        mfccs = librosa.feature.mfcc(y=audio, sr = sample_rate, n_mfcc = 40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width = ((0, 0), (0, pad_width)), mode = 'constant')
    
    except Exception as e:
        print("Error 발생: ", file_name)
        return None
    
    return mfccs

# %%
import os

# 데이터셋 path 지정
fulldatasetpath = "C:\\Users\\taemi\\capstone\\data\\3_babycry\\sounddata"

metadata = pd.read_csv("C:\\Users\\taemi\\capstone\\data\\3_babycry\\metadata_2.csv")

features = []

# 각 소리에 대해 feature를 추출
for index, row in metadata.iterrows():
    
    file_name = os.path.join(os.path.abspath(fulldatasetpath)+'/'+str(row["filename"]))
    classname = row['class']
    data = mfcc_extraction(file_name)
        
        
    features.append([data, classname])
   
 


featuresdf = pd.DataFrame(features, columns=['feature','class'])
print('Finished feature extraction from ', len(featuresdf), ' files')
# Out:
# C:\Users\taemi\anaconda3\envs\py38\lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# Finished feature extraction from  800  files

# %%
featuresdf['feature'][0]
# Out:
# array([[-306.87997  , -179.64284  , -174.84048  , ..., -126.293396 ,
#         -140.4651   , -173.81232  ],
#        [  53.31589  ,   42.146286 ,   45.98369  , ...,  -36.71096  ,
#          -37.241737 ,  -35.63836  ],
#        [ -86.9093   ,  -99.988174 ,  -95.022    , ...,  -92.13736  ,
#          -92.31154  ,  -90.11311  ],
#        ...,
#        [   6.2278433,    4.869329 ,    2.685113 , ...,    2.0053043,
#           -3.4008594,   -7.4350266],
#        [   1.2717338,   -4.257178 ,   -6.77025  , ...,   -0.4404328,
#           -2.864966 ,   -4.995389 ],
#        [   1.278897 ,    1.4378054,    2.0664775, ...,    2.2517304,
#            3.9216018,    7.808379 ]], dtype=float32)

# %%
import librosa.display
from matplotlib import pyplot as plt

plt.figure()
librosa.display.specshow(featuresdf['feature'][300], sr = 22050, x_axis='time')
plt.colorbar()
plt.title(featuresdf['class'][300])
# Out:
# Text(0.5, 1.0, 'other')

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import numpy as np
import pandas as pd


# Pandas로 저장된 각 열을 np.array로 반환
# X는 MFCC의 데이터
X = np.array(featuresdf.feature.tolist())
# Y는 그 데이터의 Label이 저장됨
y = np.array(featuresdf['class'].tolist())

# Tensorflow에 Label이 사용될 수 있도록 Label을 숫자로 인코딩 해준다.
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y))

# Test 데이터와 Train 데이터로 2:8로 나눈다.(셔플값이 디폴트이기 때문에 굳이 설정안해도 됨)
x_train, x_val, y_train, y_val = train_test_split(X, yy, test_size=0.1, random_state=1)
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.12222, random_state=1)

# %%
num_rows = 40
num_columns = 87
num_channels = 1

print("train data shape")
print(x_train.shape)
print(x_test.shape)
print(x_val.shape)

x_train = x_train.reshape(x_train.shape[0], num_rows, num_columns, num_channels)
x_test = x_test.reshape(x_test.shape[0], num_rows, num_columns, num_channels)
x_val = x_val.reshape(x_val.shape[0], num_rows, num_columns, num_channels)

print("\ntrain data reshape 결과")
print(x_train.shape)
print(x_test.shape)
print(x_val.shape)
# Out:
# train data shape
# (632, 40, 87)
# (88, 40, 87)
# (80, 40, 87)
#
# train data reshape 결과
# (632, 40, 87, 1)
# (88, 40, 87, 1)
# (80, 40, 87, 1)

# %%
# Out:
# 12

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D,Convolution2D, MaxPooling2D, GlobalAveragePooling2D, Dropout,LeakyReLU, BatchNormalization
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.utils import np_utils
from sklearn import metrics

num_labels = yy.shape[1]
filter_size = 2

# HyperParameter
EPOCHS = 1000
BATCH_SIZE = 512
MODEL_SAVE = "C:\\Users\\taemi\\capstone\\best_weight_model"
if not os.path.exists(MODEL_SAVE):
    os.mkdir(MODEL_SAVE)
    
checkpoint = ModelCheckpoint(filepath="{}/babycry_mfcc.h5".format(MODEL_SAVE), monitor="val_loss",
                             verbose=1, save_best_only=True)

ealrystopping = EarlyStopping(monitor="val_loss", patience=20)

#CNN모델 구현
model = Sequential([
    Conv2D(16, 4, padding="same", input_shape=(num_rows, num_columns, num_channels), activation=LeakyReLU(0.1)),
    MaxPooling2D(),
    Dropout(0.2),
    Conv2D(32, 1, activation="relu"),
    Conv2D(64, 2, activation="relu"),
    MaxPooling2D(),
    Dropout(0.2),
    Conv2D(128, 4, activation=LeakyReLU(0.1)),
    MaxPooling2D(),
    Dropout(0.2),
    GlobalAveragePooling2D(),
    Dense(512, activation="relu"),
    Dropout(0.2),
    Dense(1024, activation="relu"),
    Dropout(0.2),
    Dense(num_labels, activation="softmax")])



#컴파일
model.compile(loss = 'binary_crossentropy', metrics = ['accuracy'], optimizer = 'adam')  
model.summary()
history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(x_val, y_val),
          callbacks=[checkpoint, ealrystopping], verbose=1)

score = model.evaluate(x_test, y_test, verbose = 1)
accuracy = 100 * score[1]

print('Pre-training accuracy: %.4f%%' % accuracy)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 40, 87, 16)        272
#
#  max_pooling2d_9 (MaxPooling  (None, 20, 43, 16)       0
#  2D)
#
#  dropout_15 (Dropout)        (None, 20, 43, 16)        0
#
#  conv2d_12 (Conv2D)          (None, 20, 43, 32)        544
#
#  conv2d_13 (Conv2D)          (None, 19, 42, 64)        8256
#
#  max_pooling2d_10 (MaxPoolin  (None, 9, 21, 64)        0
#  g2D)
#
#  dropout_16 (Dropout)        (None, 9, 21, 64)         0
#
#  conv2d_14 (Conv2D)          (None, 6, 18, 128)        131200
#
#  max_pooling2d_11 (MaxPoolin  (None, 3, 9, 128)        0
#  g2D)
#
#  dropout_17 (Dropout)        (None, 3, 9, 128)         0
#
#  global_average_pooling2d_3   (None, 128)              0
#  (GlobalAveragePooling2D)
#
#  dense_9 (Dense)             (None, 512)               66048
#
#  dropout_18 (Dropout)        (None, 512)               0
#
#  dense_10 (Dense)            (None, 1024)              525312
#
#  dropout_19 (Dropout)        (None, 1024)              0
#
#  dense_11 (Dense)            (None, 2)                 2050
#
# =================================================================
# Total params: 733,682
# Trainable params: 733,682
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1158 - accuracy: 0.5020
# Epoch 1: val_loss improved from inf to 1.89506, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 1s 165ms/step - loss: 1.6669 - accuracy: 0.5095 - val_loss: 1.8951 - val_accuracy: 0.4375
# Epoch 2/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 2.6859 - accuracy: 0.4961
# Epoch 2: val_loss improved from 1.89506 to 0.72910, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 2.3154 - accuracy: 0.5285 - val_loss: 0.7291 - val_accuracy: 0.8375
# Epoch 3/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8936 - accuracy: 0.7324
# Epoch 3: val_loss improved from 0.72910 to 0.51366, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.8700 - accuracy: 0.7437 - val_loss: 0.5137 - val_accuracy: 0.8500
# Epoch 4/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5549 - accuracy: 0.7754
# Epoch 4: val_loss did not improve from 0.51366
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5674 - accuracy: 0.7706 - val_loss: 0.5526 - val_accuracy: 0.8375
# Epoch 5/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5950 - accuracy: 0.7832
# Epoch 5: val_loss improved from 0.51366 to 0.44227, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.5814 - accuracy: 0.7785 - val_loss: 0.4423 - val_accuracy: 0.8500
# Epoch 6/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4807 - accuracy: 0.7891
# Epoch 6: val_loss improved from 0.44227 to 0.42616, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.4781 - accuracy: 0.7880 - val_loss: 0.4262 - val_accuracy: 0.8375
# Epoch 7/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4669 - accuracy: 0.7891
# Epoch 7: val_loss improved from 0.42616 to 0.39864, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.4872 - accuracy: 0.7801 - val_loss: 0.3986 - val_accuracy: 0.8375
# Epoch 8/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4337 - accuracy: 0.8047
# Epoch 8: val_loss improved from 0.39864 to 0.38861, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.4349 - accuracy: 0.8038 - val_loss: 0.3886 - val_accuracy: 0.8500
# Epoch 9/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4331 - accuracy: 0.7949
# Epoch 9: val_loss improved from 0.38861 to 0.37708, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.4101 - accuracy: 0.8133 - val_loss: 0.3771 - val_accuracy: 0.8500
# Epoch 10/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3905 - accuracy: 0.8203
# Epoch 10: val_loss improved from 0.37708 to 0.37605, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.4037 - accuracy: 0.8212 - val_loss: 0.3760 - val_accuracy: 0.8625
# Epoch 11/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3872 - accuracy: 0.8262
# Epoch 11: val_loss improved from 0.37605 to 0.36642, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.3828 - accuracy: 0.8323 - val_loss: 0.3664 - val_accuracy: 0.8500
# Epoch 12/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3622 - accuracy: 0.8574
# Epoch 12: val_loss improved from 0.36642 to 0.36179, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.3611 - accuracy: 0.8560 - val_loss: 0.3618 - val_accuracy: 0.8875
# Epoch 13/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3330 - accuracy: 0.8652
# Epoch 13: val_loss improved from 0.36179 to 0.35075, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.3421 - accuracy: 0.8576 - val_loss: 0.3508 - val_accuracy: 0.8750
# Epoch 14/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3435 - accuracy: 0.8555
# Epoch 14: val_loss improved from 0.35075 to 0.33216, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.3293 - accuracy: 0.8623 - val_loss: 0.3322 - val_accuracy: 0.9000
# Epoch 15/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3131 - accuracy: 0.8730
# Epoch 15: val_loss did not improve from 0.33216
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3185 - accuracy: 0.8766 - val_loss: 0.3376 - val_accuracy: 0.9250
# Epoch 16/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2914 - accuracy: 0.8945
# Epoch 16: val_loss improved from 0.33216 to 0.28876, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.2997 - accuracy: 0.8861 - val_loss: 0.2888 - val_accuracy: 0.9250
# Epoch 17/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2730 - accuracy: 0.8867
# Epoch 17: val_loss did not improve from 0.28876
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2699 - accuracy: 0.8892 - val_loss: 0.3229 - val_accuracy: 0.9125
# Epoch 18/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2786 - accuracy: 0.8926
# Epoch 18: val_loss improved from 0.28876 to 0.25225, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.2599 - accuracy: 0.9019 - val_loss: 0.2523 - val_accuracy: 0.9375
# Epoch 19/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2414 - accuracy: 0.8965
# Epoch 19: val_loss did not improve from 0.25225
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2423 - accuracy: 0.9003 - val_loss: 0.2778 - val_accuracy: 0.9125
# Epoch 20/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2010 - accuracy: 0.9336
# Epoch 20: val_loss improved from 0.25225 to 0.21998, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 63ms/step - loss: 0.2069 - accuracy: 0.9288 - val_loss: 0.2200 - val_accuracy: 0.9375
# Epoch 21/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2248 - accuracy: 0.9160
# Epoch 21: val_loss did not improve from 0.21998
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2207 - accuracy: 0.9177 - val_loss: 0.3058 - val_accuracy: 0.8875
# Epoch 22/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2138 - accuracy: 0.9375
# Epoch 22: val_loss improved from 0.21998 to 0.20042, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.2089 - accuracy: 0.9351 - val_loss: 0.2004 - val_accuracy: 0.9625
# Epoch 23/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2394 - accuracy: 0.8945
# Epoch 23: val_loss did not improve from 0.20042
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2174 - accuracy: 0.9082 - val_loss: 0.3934 - val_accuracy: 0.8250
# Epoch 24/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.2192 - accuracy: 0.9121
# Epoch 24: val_loss did not improve from 0.20042
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2137 - accuracy: 0.9146 - val_loss: 0.2349 - val_accuracy: 0.9250
# Epoch 25/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1785 - accuracy: 0.9258
# Epoch 25: val_loss did not improve from 0.20042
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1757 - accuracy: 0.9288 - val_loss: 0.2451 - val_accuracy: 0.9250
# Epoch 26/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1630 - accuracy: 0.9414
# Epoch 26: val_loss did not improve from 0.20042
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1655 - accuracy: 0.9383 - val_loss: 0.2679 - val_accuracy: 0.8750
# Epoch 27/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1447 - accuracy: 0.9492
# Epoch 27: val_loss did not improve from 0.20042
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1422 - accuracy: 0.9494 - val_loss: 0.2055 - val_accuracy: 0.9500
# Epoch 28/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1539 - accuracy: 0.9414
# Epoch 28: val_loss did not improve from 0.20042
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1533 - accuracy: 0.9430 - val_loss: 0.2550 - val_accuracy: 0.8500
# Epoch 29/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1533 - accuracy: 0.9492
# Epoch 29: val_loss improved from 0.20042 to 0.15740, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1535 - accuracy: 0.9478 - val_loss: 0.1574 - val_accuracy: 0.9625
# Epoch 30/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1644 - accuracy: 0.9316
# Epoch 30: val_loss did not improve from 0.15740
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1674 - accuracy: 0.9335 - val_loss: 0.2025 - val_accuracy: 0.9250
# Epoch 31/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1240 - accuracy: 0.9570
# Epoch 31: val_loss did not improve from 0.15740
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1356 - accuracy: 0.9509 - val_loss: 0.1984 - val_accuracy: 0.9250
# Epoch 32/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1312 - accuracy: 0.9570
# Epoch 32: val_loss did not improve from 0.15740
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1277 - accuracy: 0.9557 - val_loss: 0.2237 - val_accuracy: 0.9250
# Epoch 33/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1349 - accuracy: 0.9414
# Epoch 33: val_loss did not improve from 0.15740
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1485 - accuracy: 0.9399 - val_loss: 0.2751 - val_accuracy: 0.8500
# Epoch 34/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1316 - accuracy: 0.9570
# Epoch 34: val_loss did not improve from 0.15740
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1197 - accuracy: 0.9620 - val_loss: 0.1802 - val_accuracy: 0.9625
# Epoch 35/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1402 - accuracy: 0.9473
# Epoch 35: val_loss did not improve from 0.15740
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1404 - accuracy: 0.9478 - val_loss: 0.2013 - val_accuracy: 0.9375
# Epoch 36/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1121 - accuracy: 0.9609
# Epoch 36: val_loss did not improve from 0.15740
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1106 - accuracy: 0.9620 - val_loss: 0.1584 - val_accuracy: 0.9625
# Epoch 37/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1438 - accuracy: 0.9355
# Epoch 37: val_loss did not improve from 0.15740
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1359 - accuracy: 0.9415 - val_loss: 0.4089 - val_accuracy: 0.7875
# Epoch 38/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1703 - accuracy: 0.9414
# Epoch 38: val_loss improved from 0.15740 to 0.14627, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1648 - accuracy: 0.9399 - val_loss: 0.1463 - val_accuracy: 0.9625
# Epoch 39/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1202 - accuracy: 0.9492
# Epoch 39: val_loss did not improve from 0.14627
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1176 - accuracy: 0.9541 - val_loss: 0.1854 - val_accuracy: 0.9125
# Epoch 40/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0845 - accuracy: 0.9668
# Epoch 40: val_loss did not improve from 0.14627
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0940 - accuracy: 0.9652 - val_loss: 0.1791 - val_accuracy: 0.9250
# Epoch 41/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0994 - accuracy: 0.9688
# Epoch 41: val_loss did not improve from 0.14627
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1029 - accuracy: 0.9652 - val_loss: 0.1649 - val_accuracy: 0.9250
# Epoch 42/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0963 - accuracy: 0.9629
# Epoch 42: val_loss did not improve from 0.14627
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0893 - accuracy: 0.9668 - val_loss: 0.2466 - val_accuracy: 0.8875
# Epoch 43/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1136 - accuracy: 0.9609
# Epoch 43: val_loss did not improve from 0.14627
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1004 - accuracy: 0.9684 - val_loss: 0.1598 - val_accuracy: 0.9500
# Epoch 44/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0842 - accuracy: 0.9727
# Epoch 44: val_loss did not improve from 0.14627
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0806 - accuracy: 0.9731 - val_loss: 0.2437 - val_accuracy: 0.8750
# Epoch 45/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0867 - accuracy: 0.9668
# Epoch 45: val_loss improved from 0.14627 to 0.12929, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0896 - accuracy: 0.9684 - val_loss: 0.1293 - val_accuracy: 0.9625
# Epoch 46/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0881 - accuracy: 0.9707
# Epoch 46: val_loss did not improve from 0.12929
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0995 - accuracy: 0.9668 - val_loss: 0.1634 - val_accuracy: 0.9375
# Epoch 47/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0793 - accuracy: 0.9727
# Epoch 47: val_loss did not improve from 0.12929
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0784 - accuracy: 0.9731 - val_loss: 0.1454 - val_accuracy: 0.9500
# Epoch 48/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0750 - accuracy: 0.9766
# Epoch 48: val_loss did not improve from 0.12929
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0732 - accuracy: 0.9763 - val_loss: 0.1993 - val_accuracy: 0.9125
# Epoch 49/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0785 - accuracy: 0.9707
# Epoch 49: val_loss did not improve from 0.12929
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0769 - accuracy: 0.9731 - val_loss: 0.1710 - val_accuracy: 0.9250
# Epoch 50/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0621 - accuracy: 0.9785
# Epoch 50: val_loss did not improve from 0.12929
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0597 - accuracy: 0.9794 - val_loss: 0.1786 - val_accuracy: 0.9125
# Epoch 51/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0675 - accuracy: 0.9746
# Epoch 51: val_loss did not improve from 0.12929
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0665 - accuracy: 0.9763 - val_loss: 0.2497 - val_accuracy: 0.9000
# Epoch 52/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0712 - accuracy: 0.9707
# Epoch 52: val_loss did not improve from 0.12929
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0651 - accuracy: 0.9731 - val_loss: 0.1981 - val_accuracy: 0.9125
# Epoch 53/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0647 - accuracy: 0.9785
# Epoch 53: val_loss did not improve from 0.12929
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0607 - accuracy: 0.9810 - val_loss: 0.1387 - val_accuracy: 0.9500
# Epoch 54/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0600 - accuracy: 0.9766
# Epoch 54: val_loss did not improve from 0.12929
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0608 - accuracy: 0.9778 - val_loss: 0.1918 - val_accuracy: 0.9250
# Epoch 55/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0866 - accuracy: 0.9727
# Epoch 55: val_loss improved from 0.12929 to 0.10931, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0829 - accuracy: 0.9731 - val_loss: 0.1093 - val_accuracy: 0.9750
# Epoch 56/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0804 - accuracy: 0.9648
# Epoch 56: val_loss did not improve from 0.10931
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0865 - accuracy: 0.9636 - val_loss: 0.1841 - val_accuracy: 0.9250
# Epoch 57/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1099 - accuracy: 0.9609
# Epoch 57: val_loss improved from 0.10931 to 0.09417, saving model to C:\Users\taemi\capstone\best_weight_model\babycry_mfcc.h5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1130 - accuracy: 0.9589 - val_loss: 0.0942 - val_accuracy: 0.9750
# Epoch 58/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0539 - accuracy: 0.9766
# Epoch 58: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0757 - accuracy: 0.9668 - val_loss: 0.1022 - val_accuracy: 0.9500
# Epoch 59/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0610 - accuracy: 0.9785
# Epoch 59: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0873 - accuracy: 0.9715 - val_loss: 0.1209 - val_accuracy: 0.9375
# Epoch 60/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0535 - accuracy: 0.9824
# Epoch 60: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0606 - accuracy: 0.9778 - val_loss: 0.1498 - val_accuracy: 0.9625
# Epoch 61/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1187 - accuracy: 0.9570
# Epoch 61: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1099 - accuracy: 0.9589 - val_loss: 0.4911 - val_accuracy: 0.7750
# Epoch 62/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1844 - accuracy: 0.9238
# Epoch 62: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1571 - accuracy: 0.9351 - val_loss: 0.1239 - val_accuracy: 0.9625
# Epoch 63/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0847 - accuracy: 0.9688
# Epoch 63: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0843 - accuracy: 0.9668 - val_loss: 0.1001 - val_accuracy: 0.9625
# Epoch 64/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0632 - accuracy: 0.9785
# Epoch 64: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0591 - accuracy: 0.9810 - val_loss: 0.1437 - val_accuracy: 0.9250
# Epoch 65/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0859 - accuracy: 0.9688
# Epoch 65: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0956 - accuracy: 0.9652 - val_loss: 0.0952 - val_accuracy: 0.9750
# Epoch 66/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0723 - accuracy: 0.9727
# Epoch 66: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0740 - accuracy: 0.9747 - val_loss: 0.1028 - val_accuracy: 0.9875
# Epoch 67/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0749 - accuracy: 0.9707
# Epoch 67: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0774 - accuracy: 0.9699 - val_loss: 0.1437 - val_accuracy: 0.9250
# Epoch 68/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0689 - accuracy: 0.9727
# Epoch 68: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0642 - accuracy: 0.9763 - val_loss: 0.1135 - val_accuracy: 0.9750
# Epoch 69/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0545 - accuracy: 0.9805
# Epoch 69: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0515 - accuracy: 0.9826 - val_loss: 0.1136 - val_accuracy: 0.9750
# Epoch 70/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0439 - accuracy: 0.9785
# Epoch 70: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0449 - accuracy: 0.9794 - val_loss: 0.1211 - val_accuracy: 0.9375
# Epoch 71/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0339 - accuracy: 0.9863
# Epoch 71: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0392 - accuracy: 0.9826 - val_loss: 0.1227 - val_accuracy: 0.9375
# Epoch 72/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0359 - accuracy: 0.9883
# Epoch 72: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0432 - accuracy: 0.9842 - val_loss: 0.1381 - val_accuracy: 0.9375
# Epoch 73/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0393 - accuracy: 0.9883
# Epoch 73: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0440 - accuracy: 0.9858 - val_loss: 0.1142 - val_accuracy: 0.9625
# Epoch 74/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0395 - accuracy: 0.9844
# Epoch 74: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0449 - accuracy: 0.9826 - val_loss: 0.1161 - val_accuracy: 0.9750
# Epoch 75/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0536 - accuracy: 0.9766
# Epoch 75: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0481 - accuracy: 0.9794 - val_loss: 0.1718 - val_accuracy: 0.9250
# Epoch 76/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0504 - accuracy: 0.9883
# Epoch 76: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0517 - accuracy: 0.9842 - val_loss: 0.1185 - val_accuracy: 0.9625
# Epoch 77/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0346 - accuracy: 0.9844
# Epoch 77: val_loss did not improve from 0.09417
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0391 - accuracy: 0.9810 - val_loss: 0.1211 - val_accuracy: 0.9500
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1534 - accuracy: 0.9318
# Pre-training accuracy: 93.1818%

# %%
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
model = load_model("C:\\Users\\taemi\\capstone\\best_weight_model\\babycry_mfcc.h5")
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", round(score[1]*100, 5), "%")
score = model.evaluate(x_val, y_val, verbose=0)
print("Validation Accuracy: ", round(score[1]*100, 5), "%")
score = model.evaluate(x_test, y_test, verbose=0)
print("Test Accuracy: ", round(score[1]*100, 5), "%")

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))

plt.figure(1)
plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure(2)
plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
# Out:
# Training Accuracy:  98.8924 %
# Validation Accuracy:  97.5 %
# Test Accuracy:  96.59091 %

# %%
def print_prediction(file_name):
    prediction_feature = mfcc_extraction(file_name) 
    prediction_feature = prediction_feature.reshape(1, num_rows, num_columns, num_channels)
    
    y_prob = model.predict(prediction_feature)
    predicted_vector = y_prob.argmax(axis=-1)
    
    predicted_class = le.inverse_transform(predicted_vector) 
    print("The predicted class is:", predicted_class[0], '\n') 


    predicted_proba_vector = model.predict(prediction_feature) 
    predicted_proba = predicted_proba_vector[0]
    for i in range(len(predicted_proba)): 
        category = le.inverse_transform(np.array([i]))
        print(category[0], "\t\t : ", format(predicted_proba[i], '.32f') )

# %%
def predict_prob(number):
  return [number[0],1-number[0]]

# %%
filename = 'C:\\Users\\taemi\\Documents\\소리 녹음\\meow.wav'
print_prediction(filename)
# Out:
# 1/1 [==============================] - 0s 13ms/step
# The predicted class is: other
#
# 1/1 [==============================] - 0s 12ms/step
# babycry 		 :  0.00169609626755118370056152343750
# other 		 :  0.99830389022827148437500000000000

# %%
#휴대폰 진동소리, 문여닫는소리, 초인종소리2개, 노크소리가 일단 잘안됌 12중 5개가 잘 안된다고?
