# %%
import librosa 
import numpy as np
import pandas as pd
import os

max = 0

def mel_extraction(file_name):
   
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
        
        if len(audio)/sample_rate > 2:
            audio = audio[ : sample_rate*2]
            
        S = librosa.feature.melspectrogram(y=audio, sr=sample_rate, n_mels=64, hop_length=512)
        log_S = librosa.power_to_db(S, ref=np.max)
        global max
        if log_S.shape[1] > max:
            max = log_S.shape[1]

    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
     
    return log_S

# %%
# 데이터셋 path 지정
fulldatasetpath = "C:\\Users\\taemi\\capstone\\data\\1_default\\sounddata"
metadata = pd.read_csv("C:\\Users\\taemi\\capstone\\data\\1_default\\metadata_2.csv")

features = []

    
# 각 소리에 대해 feature를 추출
for index, row in metadata.iterrows():
    
    filename = os.path.join(os.path.abspath(fulldatasetpath)+'/'+str(row["filename"]))
    classname = row["class"]
    data = mel_extraction(filename)
    
    features.append([data, classname])
    

featuresdf = pd.DataFrame(features, columns=['feature','class'])

print('Finished feature extraction from ', len(featuresdf), ' files') 
print('Max :',max)
# Out:
# C:\Users\taemi\anaconda3\envs\py38\lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# Finished feature extraction from  4577  files
# Max : 87

# %%
import pandas as pd
from collections import Counter
from matplotlib import pyplot

#클래스별 데이터 갯수 표로 표시
data = featuresdf.values
y = data[:, -1]

def count_and_plot(y): 
    counter = Counter(y)
    for k,v in counter.items():
        print('Class=%s, n=%d (%.3f%%)' % (k, v, v / len(y) * 100))
    pyplot.bar(counter.keys(), counter.values(), width=0.3)
    pyplot.xticks(np.arange(0,12), labels=counter.keys(), rotation=90)
    pyplot.show()
    
    return v

data = featuresdf.values
y = data[:, -1]

count_and_plot(y)
# Out:
# Class=dogbark, n=400 (8.739%)
# Class=scream, n=357 (7.800%)
# Class=babycry, n=400 (8.739%)
# Class=glassbreak, n=400 (8.739%)
# Class=meow, n=320 (6.991%)
# Class=knock, n=300 (6.555%)
# Class=car_horn, n=400 (8.739%)
# Class=phonevibrate, n=400 (8.739%)
# Class=door, n=400 (8.739%)
# Class=doorbell1, n=400 (8.739%)
# Class=doorbell2, n=400 (8.739%)
# Class=siren, n=400 (8.739%)
# 400

# %%
# extract feature 함수 재정의
import numpy as np
import librosa.display
max_pad_len = 87
test_num = 0

def mel_extraction(file_name):
    try:
        audio, sample_rate = librosa.load(file_name, res_type = 'kaiser_fast')
        
        if len(audio)/sample_rate > 2:
            audio = audio[ : sample_rate*2]
            
        S = librosa.feature.melspectrogram(y=audio, sr=sample_rate, n_mels=64, hop_length=512)
        log_S = librosa.power_to_db(S, ref=np.max)
        pad_width = max_pad_len - log_S.shape[1]
        log_S = np.pad(log_S, pad_width = ((0, 0), (0, pad_width)), mode = 'constant')
  
    except Exception as e:
        print("Error 발생: ", file_name)
        return None
    
    
    return log_S

# %%
import os

# 데이터셋 path 지정
fulldatasetpath = "C:\\Users\\taemi\\capstone\\data\\1_default\\sounddata"

metadata = pd.read_csv("C:\\Users\\taemi\\capstone\\data\\1_default\\metadata_2.csv")

features = []

# 각 소리에 대해 feature를 추출
for index, row in metadata.iterrows():
    
    file_name = os.path.join(os.path.abspath(fulldatasetpath)+'/'+str(row["filename"]))
    classname = row['class']
    data = mel_extraction(file_name)
        
        
    features.append([data, classname])
   
 


featuresdf = pd.DataFrame(features, columns=['feature','class'])
print('Finished feature extraction from ', len(featuresdf), ' files')
# Out:
# C:\Users\taemi\anaconda3\envs\py38\lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# Finished feature extraction from  4577  files

# %%
import librosa.display
from matplotlib import pyplot as plt

plt.figure()
librosa.display.specshow(featuresdf['feature'][300], sr = 22050, x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title(featuresdf['class'][300])
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import numpy as np
import pandas as pd


# Pandas로 저장된 각 열을 np.array로 반환
# X는 MFCC의 데이터
X = np.array(featuresdf.feature.tolist())
# Y는 그 데이터의 Label이 저장됨
y = np.array(featuresdf['class'].tolist())

# Tensorflow에 Label이 사용될 수 있도록 Label을 숫자로 인코딩 해준다.
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y))

# Test 데이터와 Train 데이터로 2:8로 나눈다.(셔플값이 디폴트이기 때문에 굳이 설정안해도 됨)
x_train, x_val, y_train, y_val = train_test_split(X, yy, test_size=0.1, random_state=1)
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.12222, random_state=1)

# %%
num_rows = 64
num_columns = 87
num_channels = 1

print("train data shape")
print(x_train.shape)
print(x_test.shape)
print(x_val.shape)

x_train = x_train.reshape(x_train.shape[0], num_rows, num_columns, num_channels)
x_test = x_test.reshape(x_test.shape[0], num_rows, num_columns, num_channels)
x_val = x_val.reshape(x_val.shape[0], num_rows, num_columns, num_channels)

print("\ntrain data reshape 결과")
print(x_train.shape)
print(x_test.shape)
print(x_val.shape)
# Out:
# train data shape
# (3615, 64, 87)
# (504, 64, 87)
# (458, 64, 87)
#
# train data reshape 결과
# (3615, 64, 87, 1)
# (504, 64, 87, 1)
# (458, 64, 87, 1)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D,Convolution2D, MaxPooling2D, GlobalAveragePooling2D, Dropout,LeakyReLU
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.utils import np_utils
from sklearn import metrics

num_labels = yy.shape[1]
filter_size = 2

# HyperParameter
EPOCHS = 1000
BATCH_SIZE = 512
MODEL_SAVE = "C:\\Users\\taemi\\capstone\\best_weight_model"
if not os.path.exists(MODEL_SAVE):
    os.mkdir(MODEL_SAVE)
    
checkpoint = ModelCheckpoint(filepath="{}/default4.h5".format(MODEL_SAVE), monitor="val_loss",
                             verbose=1, save_best_only=True)

ealrystopping = EarlyStopping(monitor="val_loss", patience=20)

#CNN모델 구현
model = Sequential()
model.add(Conv2D(filters = 16, kernel_size = 2, input_shape = (num_rows, num_columns, num_channels), activation = 'relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters = 32, kernel_size = 2, activation = 'relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters = 64, kernel_size = 2, activation = 'relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters = 128, kernel_size = 2, activation = 'relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation = 'softmax'))



#컴파일
model.compile(loss = 'categorical_crossentropy', metrics = ['accuracy'], optimizer = 'adam')  
model.summary()
history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(x_val, y_val),
          callbacks=[checkpoint, ealrystopping], verbose=1)

score = model.evaluate(x_test, y_test, verbose = 1)
accuracy = 100 * score[1]

print('Pre-training accuracy: %.4f%%' % accuracy)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 63, 86, 16)        80
#
#  max_pooling2d_9 (MaxPooling  (None, 31, 43, 16)       0
#  2D)
#
#  dropout_8 (Dropout)         (None, 31, 43, 16)        0
#
#  conv2d_10 (Conv2D)          (None, 30, 42, 32)        2080
#
#  max_pooling2d_10 (MaxPoolin  (None, 15, 21, 32)       0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 15, 21, 32)        0
#
#  conv2d_11 (Conv2D)          (None, 14, 20, 64)        8256
#
#  max_pooling2d_11 (MaxPoolin  (None, 7, 10, 64)        0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 7, 10, 64)         0
#
#  conv2d_12 (Conv2D)          (None, 6, 9, 128)         32896
#
#  max_pooling2d_12 (MaxPoolin  (None, 3, 4, 128)        0
#  g2D)
#
#  dropout_11 (Dropout)        (None, 3, 4, 128)         0
#
#  global_average_pooling2d_2   (None, 128)              0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 12)                1548
#
# =================================================================
# Total params: 44,860
# Trainable params: 44,860
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 9.3871 - accuracy: 0.0859
# Epoch 1: val_loss improved from inf to 3.27083, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 1s 46ms/step - loss: 9.3499 - accuracy: 0.0866 - val_loss: 3.2708 - val_accuracy: 0.0764
# Epoch 2/1000
# 8/8 [==============================] - ETA: 0s - loss: 5.0321 - accuracy: 0.0769
# Epoch 2: val_loss improved from 3.27083 to 2.64251, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 29ms/step - loss: 5.0321 - accuracy: 0.0769 - val_loss: 2.6425 - val_accuracy: 0.0917
# Epoch 3/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 3.2971 - accuracy: 0.0885
# Epoch 3: val_loss improved from 2.64251 to 2.61271, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 30ms/step - loss: 3.2436 - accuracy: 0.0855 - val_loss: 2.6127 - val_accuracy: 0.1004
# Epoch 4/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 2.7953 - accuracy: 0.0882
# Epoch 4: val_loss improved from 2.61271 to 2.58134, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 30ms/step - loss: 2.7939 - accuracy: 0.0877 - val_loss: 2.5813 - val_accuracy: 0.1004
# Epoch 5/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 2.5997 - accuracy: 0.1016
# Epoch 5: val_loss improved from 2.58134 to 2.52929, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 2.6001 - accuracy: 0.1010 - val_loss: 2.5293 - val_accuracy: 0.1070
# Epoch 6/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 2.5226 - accuracy: 0.1074
# Epoch 6: val_loss improved from 2.52929 to 2.51347, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 2.5216 - accuracy: 0.1076 - val_loss: 2.5135 - val_accuracy: 0.1048
# Epoch 7/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 2.4865 - accuracy: 0.1208
# Epoch 7: val_loss improved from 2.51347 to 2.48769, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 2.4865 - accuracy: 0.1198 - val_loss: 2.4877 - val_accuracy: 0.1070
# Epoch 8/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 2.4555 - accuracy: 0.1309
# Epoch 8: val_loss improved from 2.48769 to 2.46014, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 2.4547 - accuracy: 0.1344 - val_loss: 2.4601 - val_accuracy: 0.1092
# Epoch 9/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 2.4111 - accuracy: 0.1377
# Epoch 9: val_loss improved from 2.46014 to 2.42606, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 2.4073 - accuracy: 0.1380 - val_loss: 2.4261 - val_accuracy: 0.1179
# Epoch 10/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 2.3576 - accuracy: 0.1629
# Epoch 10: val_loss improved from 2.42606 to 2.37059, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 2.3591 - accuracy: 0.1629 - val_loss: 2.3706 - val_accuracy: 0.2074
# Epoch 11/1000
# 8/8 [==============================] - ETA: 0s - loss: 2.3037 - accuracy: 0.1884
# Epoch 11: val_loss improved from 2.37059 to 2.32563, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 2.3037 - accuracy: 0.1884 - val_loss: 2.3256 - val_accuracy: 0.2205
# Epoch 12/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 2.2294 - accuracy: 0.1925
# Epoch 12: val_loss improved from 2.32563 to 2.28050, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 2.2289 - accuracy: 0.1931 - val_loss: 2.2805 - val_accuracy: 0.2424
# Epoch 13/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 2.1686 - accuracy: 0.2377
# Epoch 13: val_loss improved from 2.28050 to 2.23622, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 2.1691 - accuracy: 0.2371 - val_loss: 2.2362 - val_accuracy: 0.2511
# Epoch 14/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 2.0982 - accuracy: 0.2547
# Epoch 14: val_loss improved from 2.23622 to 2.15819, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 33ms/step - loss: 2.0994 - accuracy: 0.2545 - val_loss: 2.1582 - val_accuracy: 0.2598
# Epoch 15/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 2.0338 - accuracy: 0.2709
# Epoch 15: val_loss improved from 2.15819 to 2.09250, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 2.0318 - accuracy: 0.2711 - val_loss: 2.0925 - val_accuracy: 0.2838
# Epoch 16/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.9447 - accuracy: 0.3131
# Epoch 16: val_loss improved from 2.09250 to 2.08885, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 33ms/step - loss: 1.9463 - accuracy: 0.3118 - val_loss: 2.0889 - val_accuracy: 0.2642
# Epoch 17/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.9305 - accuracy: 0.3027
# Epoch 17: val_loss improved from 2.08885 to 2.01110, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 1.9315 - accuracy: 0.3029 - val_loss: 2.0111 - val_accuracy: 0.2948
# Epoch 18/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.8483 - accuracy: 0.3471
# Epoch 18: val_loss improved from 2.01110 to 1.94648, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 1.8479 - accuracy: 0.3474 - val_loss: 1.9465 - val_accuracy: 0.3122
# Epoch 19/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.8039 - accuracy: 0.3610
# Epoch 19: val_loss improved from 1.94648 to 1.90687, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 1.8042 - accuracy: 0.3613 - val_loss: 1.9069 - val_accuracy: 0.3341
# Epoch 20/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.7798 - accuracy: 0.3903
# Epoch 20: val_loss improved from 1.90687 to 1.87110, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 1.7800 - accuracy: 0.3898 - val_loss: 1.8711 - val_accuracy: 0.3384
# Epoch 21/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.7336 - accuracy: 0.3728
# Epoch 21: val_loss improved from 1.87110 to 1.81669, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 1.7340 - accuracy: 0.3729 - val_loss: 1.8167 - val_accuracy: 0.3668
# Epoch 22/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.6833 - accuracy: 0.4266
# Epoch 22: val_loss did not improve from 1.81669
# 8/8 [==============================] - 0s 31ms/step - loss: 1.6841 - accuracy: 0.4266 - val_loss: 1.8176 - val_accuracy: 0.3646
# Epoch 23/1000
# 8/8 [==============================] - ETA: 0s - loss: 1.7536 - accuracy: 0.3920
# Epoch 23: val_loss improved from 1.81669 to 1.79433, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 33ms/step - loss: 1.7536 - accuracy: 0.3920 - val_loss: 1.7943 - val_accuracy: 0.3603
# Epoch 24/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.6583 - accuracy: 0.4152
# Epoch 24: val_loss improved from 1.79433 to 1.74727, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 30ms/step - loss: 1.6581 - accuracy: 0.4155 - val_loss: 1.7473 - val_accuracy: 0.3865
# Epoch 25/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.6362 - accuracy: 0.4406
# Epoch 25: val_loss improved from 1.74727 to 1.66535, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 33ms/step - loss: 1.6359 - accuracy: 0.4409 - val_loss: 1.6654 - val_accuracy: 0.4541
# Epoch 26/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 1.5648 - accuracy: 0.4661
# Epoch 26: val_loss improved from 1.66535 to 1.63284, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 1.5599 - accuracy: 0.4653 - val_loss: 1.6328 - val_accuracy: 0.4607
# Epoch 27/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.5250 - accuracy: 0.4729
# Epoch 27: val_loss improved from 1.63284 to 1.61054, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 1.5256 - accuracy: 0.4722 - val_loss: 1.6105 - val_accuracy: 0.4520
# Epoch 28/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.4644 - accuracy: 0.5025
# Epoch 28: val_loss improved from 1.61054 to 1.54357, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 1.4626 - accuracy: 0.5021 - val_loss: 1.5436 - val_accuracy: 0.5131
# Epoch 29/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.4443 - accuracy: 0.4994
# Epoch 29: val_loss improved from 1.54357 to 1.49880, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 1.4446 - accuracy: 0.4996 - val_loss: 1.4988 - val_accuracy: 0.5197
# Epoch 30/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.4164 - accuracy: 0.5209
# Epoch 30: val_loss improved from 1.49880 to 1.46174, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 30ms/step - loss: 1.4154 - accuracy: 0.5214 - val_loss: 1.4617 - val_accuracy: 0.5611
# Epoch 31/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.3483 - accuracy: 0.5474
# Epoch 31: val_loss did not improve from 1.46174
# 8/8 [==============================] - 0s 26ms/step - loss: 1.3472 - accuracy: 0.5474 - val_loss: 1.4755 - val_accuracy: 0.5087
# Epoch 32/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.3360 - accuracy: 0.5480
# Epoch 32: val_loss improved from 1.46174 to 1.36853, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 1.3360 - accuracy: 0.5483 - val_loss: 1.3685 - val_accuracy: 0.6397
# Epoch 33/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.3272 - accuracy: 0.5480
# Epoch 33: val_loss improved from 1.36853 to 1.36094, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 33ms/step - loss: 1.3271 - accuracy: 0.5480 - val_loss: 1.3609 - val_accuracy: 0.5786
# Epoch 34/1000
# 8/8 [==============================] - ETA: 0s - loss: 1.2521 - accuracy: 0.5878
# Epoch 34: val_loss improved from 1.36094 to 1.33860, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 1.2521 - accuracy: 0.5878 - val_loss: 1.3386 - val_accuracy: 0.5633
# Epoch 35/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 1.2137 - accuracy: 0.5915
# Epoch 35: val_loss improved from 1.33860 to 1.24816, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 30ms/step - loss: 1.2142 - accuracy: 0.5936 - val_loss: 1.2482 - val_accuracy: 0.6223
# Epoch 36/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.1857 - accuracy: 0.6007
# Epoch 36: val_loss improved from 1.24816 to 1.21375, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 36ms/step - loss: 1.1818 - accuracy: 0.6019 - val_loss: 1.2137 - val_accuracy: 0.6725
# Epoch 37/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.1295 - accuracy: 0.6297
# Epoch 37: val_loss did not improve from 1.21375
# 8/8 [==============================] - 0s 28ms/step - loss: 1.1275 - accuracy: 0.6307 - val_loss: 1.2273 - val_accuracy: 0.6288
# Epoch 38/1000
# 8/8 [==============================] - ETA: 0s - loss: 1.0948 - accuracy: 0.6257
# Epoch 38: val_loss improved from 1.21375 to 1.18992, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 1.0948 - accuracy: 0.6257 - val_loss: 1.1899 - val_accuracy: 0.6332
# Epoch 39/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.0676 - accuracy: 0.6476
# Epoch 39: val_loss did not improve from 1.18992
# 8/8 [==============================] - 0s 26ms/step - loss: 1.0702 - accuracy: 0.6462 - val_loss: 1.2151 - val_accuracy: 0.6266
# Epoch 40/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 1.0941 - accuracy: 0.6413
# Epoch 40: val_loss improved from 1.18992 to 1.15567, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 1.0723 - accuracy: 0.6506 - val_loss: 1.1557 - val_accuracy: 0.6747
# Epoch 41/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.0418 - accuracy: 0.6588
# Epoch 41: val_loss improved from 1.15567 to 1.04376, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 30ms/step - loss: 1.0412 - accuracy: 0.6598 - val_loss: 1.0438 - val_accuracy: 0.7140
# Epoch 42/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.9742 - accuracy: 0.6829
# Epoch 42: val_loss improved from 1.04376 to 1.04236, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 29ms/step - loss: 0.9635 - accuracy: 0.6885 - val_loss: 1.0424 - val_accuracy: 0.7031
# Epoch 43/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.9612 - accuracy: 0.6811
# Epoch 43: val_loss did not improve from 1.04236
# 8/8 [==============================] - 0s 29ms/step - loss: 0.9644 - accuracy: 0.6802 - val_loss: 1.0970 - val_accuracy: 0.6856
# Epoch 44/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.9548 - accuracy: 0.6925
# Epoch 44: val_loss improved from 1.04236 to 0.94301, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 0.9540 - accuracy: 0.6924 - val_loss: 0.9430 - val_accuracy: 0.7314
# Epoch 45/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.9131 - accuracy: 0.7107
# Epoch 45: val_loss did not improve from 0.94301
# 8/8 [==============================] - 0s 27ms/step - loss: 0.9131 - accuracy: 0.7107 - val_loss: 0.9556 - val_accuracy: 0.7052
# Epoch 46/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.8793 - accuracy: 0.7140
# Epoch 46: val_loss improved from 0.94301 to 0.85576, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 0.8823 - accuracy: 0.7118 - val_loss: 0.8558 - val_accuracy: 0.7707
# Epoch 47/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.9003 - accuracy: 0.7067
# Epoch 47: val_loss did not improve from 0.85576
# 8/8 [==============================] - 0s 27ms/step - loss: 0.8860 - accuracy: 0.7131 - val_loss: 0.9289 - val_accuracy: 0.7205
# Epoch 48/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.8830 - accuracy: 0.7174
# Epoch 48: val_loss improved from 0.85576 to 0.83699, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 0.8803 - accuracy: 0.7181 - val_loss: 0.8370 - val_accuracy: 0.7620
# Epoch 49/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.8286 - accuracy: 0.7377
# Epoch 49: val_loss did not improve from 0.83699
# 8/8 [==============================] - 0s 27ms/step - loss: 0.8303 - accuracy: 0.7378 - val_loss: 0.8649 - val_accuracy: 0.7445
# Epoch 50/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.8058 - accuracy: 0.7335
# Epoch 50: val_loss did not improve from 0.83699
# 8/8 [==============================] - 0s 27ms/step - loss: 0.8051 - accuracy: 0.7339 - val_loss: 0.8983 - val_accuracy: 0.7271
# Epoch 51/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.7653 - accuracy: 0.7659
# Epoch 51: val_loss did not improve from 0.83699
# 8/8 [==============================] - 0s 28ms/step - loss: 0.7653 - accuracy: 0.7660 - val_loss: 0.8858 - val_accuracy: 0.7358
# Epoch 52/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.7832 - accuracy: 0.7377
# Epoch 52: val_loss did not improve from 0.83699
# 8/8 [==============================] - 0s 28ms/step - loss: 0.7819 - accuracy: 0.7389 - val_loss: 0.8817 - val_accuracy: 0.7227
# Epoch 53/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.7969 - accuracy: 0.7513
# Epoch 53: val_loss improved from 0.83699 to 0.83196, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 29ms/step - loss: 0.7833 - accuracy: 0.7521 - val_loss: 0.8320 - val_accuracy: 0.7424
# Epoch 54/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.7573 - accuracy: 0.7520
# Epoch 54: val_loss did not improve from 0.83196
# 8/8 [==============================] - 0s 27ms/step - loss: 0.7589 - accuracy: 0.7510 - val_loss: 0.8815 - val_accuracy: 0.7314
# Epoch 55/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.7451 - accuracy: 0.7550
# Epoch 55: val_loss improved from 0.83196 to 0.81039, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 0.7441 - accuracy: 0.7544 - val_loss: 0.8104 - val_accuracy: 0.7576
# Epoch 56/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.6850 - accuracy: 0.7913
# Epoch 56: val_loss improved from 0.81039 to 0.75635, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6850 - accuracy: 0.7909 - val_loss: 0.7564 - val_accuracy: 0.7838
# Epoch 57/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.6826 - accuracy: 0.7884
# Epoch 57: val_loss did not improve from 0.75635
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6699 - accuracy: 0.7939 - val_loss: 0.7574 - val_accuracy: 0.7882
# Epoch 58/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.6683 - accuracy: 0.7986
# Epoch 58: val_loss improved from 0.75635 to 0.69444, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6683 - accuracy: 0.7986 - val_loss: 0.6944 - val_accuracy: 0.8057
# Epoch 59/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.6557 - accuracy: 0.7896
# Epoch 59: val_loss did not improve from 0.69444
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6538 - accuracy: 0.7906 - val_loss: 0.6952 - val_accuracy: 0.7969
# Epoch 60/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.6521 - accuracy: 0.7877
# Epoch 60: val_loss improved from 0.69444 to 0.67280, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6534 - accuracy: 0.7867 - val_loss: 0.6728 - val_accuracy: 0.8079
# Epoch 61/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.6349 - accuracy: 0.7977
# Epoch 61: val_loss improved from 0.67280 to 0.66701, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6360 - accuracy: 0.7970 - val_loss: 0.6670 - val_accuracy: 0.8013
# Epoch 62/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.6068 - accuracy: 0.8052
# Epoch 62: val_loss improved from 0.66701 to 0.64284, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6064 - accuracy: 0.8053 - val_loss: 0.6428 - val_accuracy: 0.8253
# Epoch 63/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.6098 - accuracy: 0.8019
# Epoch 63: val_loss improved from 0.64284 to 0.63967, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6089 - accuracy: 0.8019 - val_loss: 0.6397 - val_accuracy: 0.8231
# Epoch 64/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.5701 - accuracy: 0.8211
# Epoch 64: val_loss improved from 0.63967 to 0.58578, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 0.5708 - accuracy: 0.8210 - val_loss: 0.5858 - val_accuracy: 0.8450
# Epoch 65/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.6372 - accuracy: 0.7927
# Epoch 65: val_loss did not improve from 0.58578
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6372 - accuracy: 0.7928 - val_loss: 0.6411 - val_accuracy: 0.8253
# Epoch 66/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.6117 - accuracy: 0.8066
# Epoch 66: val_loss did not improve from 0.58578
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6140 - accuracy: 0.8055 - val_loss: 0.5870 - val_accuracy: 0.8406
# Epoch 67/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.5817 - accuracy: 0.8122
# Epoch 67: val_loss did not improve from 0.58578
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5835 - accuracy: 0.8119 - val_loss: 0.5868 - val_accuracy: 0.8297
# Epoch 68/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.5742 - accuracy: 0.8136
# Epoch 68: val_loss did not improve from 0.58578
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5732 - accuracy: 0.8144 - val_loss: 0.6477 - val_accuracy: 0.8100
# Epoch 69/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.5600 - accuracy: 0.8301
# Epoch 69: val_loss did not improve from 0.58578
# 8/8 [==============================] - 0s 29ms/step - loss: 0.5576 - accuracy: 0.8313 - val_loss: 0.6730 - val_accuracy: 0.8035
# Epoch 70/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.5570 - accuracy: 0.8251
# Epoch 70: val_loss improved from 0.58578 to 0.53893, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5566 - accuracy: 0.8254 - val_loss: 0.5389 - val_accuracy: 0.8559
# Epoch 71/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.5456 - accuracy: 0.8229
# Epoch 71: val_loss did not improve from 0.53893
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5426 - accuracy: 0.8246 - val_loss: 0.5588 - val_accuracy: 0.8472
# Epoch 72/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.5510 - accuracy: 0.8310
# Epoch 72: val_loss did not improve from 0.53893
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5510 - accuracy: 0.8310 - val_loss: 0.6537 - val_accuracy: 0.8253
# Epoch 73/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.5165 - accuracy: 0.8331
# Epoch 73: val_loss improved from 0.53893 to 0.53541, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5177 - accuracy: 0.8329 - val_loss: 0.5354 - val_accuracy: 0.8581
# Epoch 74/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.5101 - accuracy: 0.8432
# Epoch 74: val_loss did not improve from 0.53541
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5127 - accuracy: 0.8423 - val_loss: 0.5706 - val_accuracy: 0.8384
# Epoch 75/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4865 - accuracy: 0.8479
# Epoch 75: val_loss did not improve from 0.53541
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4862 - accuracy: 0.8481 - val_loss: 0.5846 - val_accuracy: 0.8406
# Epoch 76/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4855 - accuracy: 0.8465
# Epoch 76: val_loss did not improve from 0.53541
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4845 - accuracy: 0.8470 - val_loss: 0.5677 - val_accuracy: 0.8493
# Epoch 77/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4902 - accuracy: 0.8493
# Epoch 77: val_loss did not improve from 0.53541
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4888 - accuracy: 0.8495 - val_loss: 0.5833 - val_accuracy: 0.8319
# Epoch 78/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.4849 - accuracy: 0.8467
# Epoch 78: val_loss did not improve from 0.53541
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4849 - accuracy: 0.8467 - val_loss: 0.5753 - val_accuracy: 0.8406
# Epoch 79/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4936 - accuracy: 0.8465
# Epoch 79: val_loss improved from 0.53541 to 0.51851, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 0.4927 - accuracy: 0.8470 - val_loss: 0.5185 - val_accuracy: 0.8559
# Epoch 80/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4525 - accuracy: 0.8608
# Epoch 80: val_loss improved from 0.51851 to 0.46252, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 35ms/step - loss: 0.4519 - accuracy: 0.8611 - val_loss: 0.4625 - val_accuracy: 0.8799
# Epoch 81/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4544 - accuracy: 0.8610
# Epoch 81: val_loss did not improve from 0.46252
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4568 - accuracy: 0.8603 - val_loss: 0.5395 - val_accuracy: 0.8559
# Epoch 82/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4740 - accuracy: 0.8485
# Epoch 82: val_loss did not improve from 0.46252
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4779 - accuracy: 0.8476 - val_loss: 0.4970 - val_accuracy: 0.8624
# Epoch 83/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4916 - accuracy: 0.8410
# Epoch 83: val_loss did not improve from 0.46252
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4939 - accuracy: 0.8401 - val_loss: 0.4932 - val_accuracy: 0.8515
# Epoch 84/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4838 - accuracy: 0.8460
# Epoch 84: val_loss did not improve from 0.46252
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4832 - accuracy: 0.8465 - val_loss: 0.5508 - val_accuracy: 0.8297
# Epoch 85/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4267 - accuracy: 0.8644
# Epoch 85: val_loss did not improve from 0.46252
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4275 - accuracy: 0.8642 - val_loss: 0.5545 - val_accuracy: 0.8515
# Epoch 86/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4501 - accuracy: 0.8571
# Epoch 86: val_loss improved from 0.46252 to 0.44651, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4498 - accuracy: 0.8575 - val_loss: 0.4465 - val_accuracy: 0.8843
# Epoch 87/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4383 - accuracy: 0.8652
# Epoch 87: val_loss improved from 0.44651 to 0.42543, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 0.4404 - accuracy: 0.8650 - val_loss: 0.4254 - val_accuracy: 0.8865
# Epoch 88/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4888 - accuracy: 0.8491
# Epoch 88: val_loss did not improve from 0.42543
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4913 - accuracy: 0.8492 - val_loss: 0.4968 - val_accuracy: 0.8515
# Epoch 89/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4576 - accuracy: 0.8510
# Epoch 89: val_loss did not improve from 0.42543
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4587 - accuracy: 0.8503 - val_loss: 0.5527 - val_accuracy: 0.8428
# Epoch 90/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.4427 - accuracy: 0.8617
# Epoch 90: val_loss did not improve from 0.42543
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4401 - accuracy: 0.8631 - val_loss: 0.4460 - val_accuracy: 0.8755
# Epoch 91/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4171 - accuracy: 0.8683
# Epoch 91: val_loss improved from 0.42543 to 0.42340, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 0.4214 - accuracy: 0.8669 - val_loss: 0.4234 - val_accuracy: 0.8799
# Epoch 92/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.4319 - accuracy: 0.8586
# Epoch 92: val_loss improved from 0.42340 to 0.42277, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4319 - accuracy: 0.8586 - val_loss: 0.4228 - val_accuracy: 0.8821
# Epoch 93/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4009 - accuracy: 0.8778
# Epoch 93: val_loss improved from 0.42277 to 0.40408, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4011 - accuracy: 0.8777 - val_loss: 0.4041 - val_accuracy: 0.8886
# Epoch 94/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.3966 - accuracy: 0.8722
# Epoch 94: val_loss did not improve from 0.40408
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3966 - accuracy: 0.8722 - val_loss: 0.4594 - val_accuracy: 0.8734
# Epoch 95/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3961 - accuracy: 0.8786
# Epoch 95: val_loss improved from 0.40408 to 0.37690, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3981 - accuracy: 0.8777 - val_loss: 0.3769 - val_accuracy: 0.9061
# Epoch 96/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.3937 - accuracy: 0.8694
# Epoch 96: val_loss did not improve from 0.37690
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3937 - accuracy: 0.8694 - val_loss: 0.4820 - val_accuracy: 0.8668
# Epoch 97/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.3921 - accuracy: 0.8792
# Epoch 97: val_loss did not improve from 0.37690
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3885 - accuracy: 0.8799 - val_loss: 0.3777 - val_accuracy: 0.8974
# Epoch 98/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3872 - accuracy: 0.8825
# Epoch 98: val_loss did not improve from 0.37690
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3873 - accuracy: 0.8822 - val_loss: 0.4471 - val_accuracy: 0.8712
# Epoch 99/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3782 - accuracy: 0.8800
# Epoch 99: val_loss did not improve from 0.37690
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3765 - accuracy: 0.8808 - val_loss: 0.3884 - val_accuracy: 0.8930
# Epoch 100/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3646 - accuracy: 0.8873
# Epoch 100: val_loss did not improve from 0.37690
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3638 - accuracy: 0.8871 - val_loss: 0.3782 - val_accuracy: 0.8974
# Epoch 101/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3547 - accuracy: 0.8901
# Epoch 101: val_loss improved from 0.37690 to 0.37640, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3535 - accuracy: 0.8907 - val_loss: 0.3764 - val_accuracy: 0.8974
# Epoch 102/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3400 - accuracy: 0.8892
# Epoch 102: val_loss did not improve from 0.37640
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3395 - accuracy: 0.8891 - val_loss: 0.4064 - val_accuracy: 0.8821
# Epoch 103/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.3722 - accuracy: 0.8783
# Epoch 103: val_loss improved from 0.37640 to 0.35072, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3722 - accuracy: 0.8783 - val_loss: 0.3507 - val_accuracy: 0.8996
# Epoch 104/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3347 - accuracy: 0.8929
# Epoch 104: val_loss did not improve from 0.35072
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3349 - accuracy: 0.8929 - val_loss: 0.3862 - val_accuracy: 0.8755
# Epoch 105/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3532 - accuracy: 0.8954
# Epoch 105: val_loss improved from 0.35072 to 0.33434, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3521 - accuracy: 0.8957 - val_loss: 0.3343 - val_accuracy: 0.9192
# Epoch 106/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3386 - accuracy: 0.8923
# Epoch 106: val_loss did not improve from 0.33434
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3381 - accuracy: 0.8927 - val_loss: 0.3604 - val_accuracy: 0.8952
# Epoch 107/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3431 - accuracy: 0.8943
# Epoch 107: val_loss did not improve from 0.33434
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3439 - accuracy: 0.8941 - val_loss: 0.3931 - val_accuracy: 0.8996
# Epoch 108/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3624 - accuracy: 0.8850
# Epoch 108: val_loss improved from 0.33434 to 0.30628, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3624 - accuracy: 0.8852 - val_loss: 0.3063 - val_accuracy: 0.9127
# Epoch 109/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.3393 - accuracy: 0.8929
# Epoch 109: val_loss did not improve from 0.30628
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3393 - accuracy: 0.8929 - val_loss: 0.3912 - val_accuracy: 0.8821
# Epoch 110/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.3232 - accuracy: 0.9010
# Epoch 110: val_loss did not improve from 0.30628
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3290 - accuracy: 0.8990 - val_loss: 0.3214 - val_accuracy: 0.9105
# Epoch 111/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3225 - accuracy: 0.9015
# Epoch 111: val_loss did not improve from 0.30628
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3236 - accuracy: 0.9007 - val_loss: 0.3235 - val_accuracy: 0.9039
# Epoch 112/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.3439 - accuracy: 0.8923
# Epoch 112: val_loss did not improve from 0.30628
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3413 - accuracy: 0.8921 - val_loss: 0.3280 - val_accuracy: 0.9214
# Epoch 113/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.3337 - accuracy: 0.8945
# Epoch 113: val_loss did not improve from 0.30628
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3336 - accuracy: 0.8941 - val_loss: 0.3250 - val_accuracy: 0.9105
# Epoch 114/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3470 - accuracy: 0.8848
# Epoch 114: val_loss did not improve from 0.30628
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3455 - accuracy: 0.8852 - val_loss: 0.3416 - val_accuracy: 0.9083
# Epoch 115/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3164 - accuracy: 0.8979
# Epoch 115: val_loss did not improve from 0.30628
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3158 - accuracy: 0.8979 - val_loss: 0.3553 - val_accuracy: 0.9017
# Epoch 116/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.3461 - accuracy: 0.8923
# Epoch 116: val_loss did not improve from 0.30628
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3437 - accuracy: 0.8918 - val_loss: 0.3131 - val_accuracy: 0.9214
# Epoch 117/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.3224 - accuracy: 0.8942
# Epoch 117: val_loss improved from 0.30628 to 0.28806, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3207 - accuracy: 0.8960 - val_loss: 0.2881 - val_accuracy: 0.9170
# Epoch 118/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.3226 - accuracy: 0.8957
# Epoch 118: val_loss improved from 0.28806 to 0.28762, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3226 - accuracy: 0.8957 - val_loss: 0.2876 - val_accuracy: 0.9279
# Epoch 119/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.3087 - accuracy: 0.9065
# Epoch 119: val_loss did not improve from 0.28762
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3087 - accuracy: 0.9065 - val_loss: 0.3139 - val_accuracy: 0.9039
# Epoch 120/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3066 - accuracy: 0.8976
# Epoch 120: val_loss did not improve from 0.28762
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3057 - accuracy: 0.8979 - val_loss: 0.3307 - val_accuracy: 0.9061
# Epoch 121/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.3155 - accuracy: 0.8999
# Epoch 121: val_loss improved from 0.28762 to 0.28559, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3155 - accuracy: 0.8999 - val_loss: 0.2856 - val_accuracy: 0.9258
# Epoch 122/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.3014 - accuracy: 0.9029
# Epoch 122: val_loss did not improve from 0.28559
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3014 - accuracy: 0.9029 - val_loss: 0.3123 - val_accuracy: 0.9192
# Epoch 123/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.2801 - accuracy: 0.9129
# Epoch 123: val_loss improved from 0.28559 to 0.28131, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2801 - accuracy: 0.9129 - val_loss: 0.2813 - val_accuracy: 0.9170
# Epoch 124/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2896 - accuracy: 0.9079
# Epoch 124: val_loss did not improve from 0.28131
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2889 - accuracy: 0.9082 - val_loss: 0.2996 - val_accuracy: 0.9170
# Epoch 125/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.2926 - accuracy: 0.9108
# Epoch 125: val_loss did not improve from 0.28131
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2862 - accuracy: 0.9123 - val_loss: 0.3093 - val_accuracy: 0.9105
# Epoch 126/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.2992 - accuracy: 0.9024
# Epoch 126: val_loss did not improve from 0.28131
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2992 - accuracy: 0.9024 - val_loss: 0.2857 - val_accuracy: 0.9192
# Epoch 127/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.2905 - accuracy: 0.9033
# Epoch 127: val_loss improved from 0.28131 to 0.27614, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2828 - accuracy: 0.9071 - val_loss: 0.2761 - val_accuracy: 0.9192
# Epoch 128/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2789 - accuracy: 0.9076
# Epoch 128: val_loss did not improve from 0.27614
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2799 - accuracy: 0.9076 - val_loss: 0.2966 - val_accuracy: 0.9192
# Epoch 129/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.2833 - accuracy: 0.9084
# Epoch 129: val_loss improved from 0.27614 to 0.26097, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2833 - accuracy: 0.9084 - val_loss: 0.2610 - val_accuracy: 0.9345
# Epoch 130/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2811 - accuracy: 0.9071
# Epoch 130: val_loss did not improve from 0.26097
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2819 - accuracy: 0.9068 - val_loss: 0.2815 - val_accuracy: 0.9192
# Epoch 131/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2912 - accuracy: 0.9018
# Epoch 131: val_loss did not improve from 0.26097
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2897 - accuracy: 0.9024 - val_loss: 0.2644 - val_accuracy: 0.9345
# Epoch 132/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2883 - accuracy: 0.9035
# Epoch 132: val_loss did not improve from 0.26097
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2888 - accuracy: 0.9032 - val_loss: 0.2634 - val_accuracy: 0.9192
# Epoch 133/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.2784 - accuracy: 0.9076
# Epoch 133: val_loss did not improve from 0.26097
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2784 - accuracy: 0.9076 - val_loss: 0.3020 - val_accuracy: 0.9258
# Epoch 134/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2807 - accuracy: 0.9074
# Epoch 134: val_loss did not improve from 0.26097
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2804 - accuracy: 0.9076 - val_loss: 0.2725 - val_accuracy: 0.9214
# Epoch 135/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2574 - accuracy: 0.9118
# Epoch 135: val_loss improved from 0.26097 to 0.25019, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2566 - accuracy: 0.9123 - val_loss: 0.2502 - val_accuracy: 0.9323
# Epoch 136/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2554 - accuracy: 0.9199
# Epoch 136: val_loss improved from 0.25019 to 0.24133, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2549 - accuracy: 0.9201 - val_loss: 0.2413 - val_accuracy: 0.9323
# Epoch 137/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2758 - accuracy: 0.9118
# Epoch 137: val_loss did not improve from 0.24133
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2750 - accuracy: 0.9120 - val_loss: 0.2890 - val_accuracy: 0.9192
# Epoch 138/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2564 - accuracy: 0.9163
# Epoch 138: val_loss improved from 0.24133 to 0.23247, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2559 - accuracy: 0.9165 - val_loss: 0.2325 - val_accuracy: 0.9323
# Epoch 139/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2580 - accuracy: 0.9132
# Epoch 139: val_loss did not improve from 0.23247
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2566 - accuracy: 0.9140 - val_loss: 0.2364 - val_accuracy: 0.9323
# Epoch 140/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2446 - accuracy: 0.9238
# Epoch 140: val_loss improved from 0.23247 to 0.22390, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2470 - accuracy: 0.9234 - val_loss: 0.2239 - val_accuracy: 0.9345
# Epoch 141/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2456 - accuracy: 0.9208
# Epoch 141: val_loss did not improve from 0.22390
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2456 - accuracy: 0.9209 - val_loss: 0.2550 - val_accuracy: 0.9279
# Epoch 142/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2410 - accuracy: 0.9216
# Epoch 142: val_loss did not improve from 0.22390
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2403 - accuracy: 0.9220 - val_loss: 0.2349 - val_accuracy: 0.9367
# Epoch 143/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.2642 - accuracy: 0.9199
# Epoch 143: val_loss did not improve from 0.22390
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2544 - accuracy: 0.9225 - val_loss: 0.2557 - val_accuracy: 0.9301
# Epoch 144/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2731 - accuracy: 0.9129
# Epoch 144: val_loss did not improve from 0.22390
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2713 - accuracy: 0.9137 - val_loss: 0.2406 - val_accuracy: 0.9279
# Epoch 145/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2202 - accuracy: 0.9280
# Epoch 145: val_loss improved from 0.22390 to 0.20991, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2199 - accuracy: 0.9284 - val_loss: 0.2099 - val_accuracy: 0.9301
# Epoch 146/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.2388 - accuracy: 0.9225
# Epoch 146: val_loss did not improve from 0.20991
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2349 - accuracy: 0.9228 - val_loss: 0.2674 - val_accuracy: 0.9214
# Epoch 147/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.2278 - accuracy: 0.9261
# ...
# Epoch 286/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1102 - accuracy: 0.9595
# Epoch 286: val_loss did not improve from 0.11043
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1096 - accuracy: 0.9599 - val_loss: 0.1240 - val_accuracy: 0.9585
# Epoch 287/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1055 - accuracy: 0.9660
# Epoch 287: val_loss did not improve from 0.11043
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1055 - accuracy: 0.9660 - val_loss: 0.1430 - val_accuracy: 0.9629
# Epoch 288/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1034 - accuracy: 0.9660
# Epoch 288: val_loss improved from 0.11043 to 0.10206, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1029 - accuracy: 0.9663 - val_loss: 0.1021 - val_accuracy: 0.9651
# Epoch 289/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0910 - accuracy: 0.9701
# Epoch 289: val_loss did not improve from 0.10206
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0913 - accuracy: 0.9701 - val_loss: 0.1269 - val_accuracy: 0.9607
# Epoch 290/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.1118 - accuracy: 0.9629
# Epoch 290: val_loss did not improve from 0.10206
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1111 - accuracy: 0.9638 - val_loss: 0.1241 - val_accuracy: 0.9607
# Epoch 291/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1031 - accuracy: 0.9688
# Epoch 291: val_loss did not improve from 0.10206
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1032 - accuracy: 0.9687 - val_loss: 0.1042 - val_accuracy: 0.9672
# Epoch 292/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.1044 - accuracy: 0.9648
# Epoch 292: val_loss did not improve from 0.10206
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1021 - accuracy: 0.9665 - val_loss: 0.1138 - val_accuracy: 0.9629
# Epoch 293/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.1033 - accuracy: 0.9648
# Epoch 293: val_loss did not improve from 0.10206
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1028 - accuracy: 0.9654 - val_loss: 0.1272 - val_accuracy: 0.9585
# Epoch 294/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.1016 - accuracy: 0.9639
# Epoch 294: val_loss did not improve from 0.10206
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1059 - accuracy: 0.9624 - val_loss: 0.1180 - val_accuracy: 0.9629
# Epoch 295/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1034 - accuracy: 0.9674
# Epoch 295: val_loss did not improve from 0.10206
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1026 - accuracy: 0.9676 - val_loss: 0.1268 - val_accuracy: 0.9629
# Epoch 296/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.0974 - accuracy: 0.9674
# Epoch 296: val_loss did not improve from 0.10206
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0950 - accuracy: 0.9682 - val_loss: 0.1066 - val_accuracy: 0.9694
# Epoch 297/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.1046 - accuracy: 0.9626
# Epoch 297: val_loss did not improve from 0.10206
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1043 - accuracy: 0.9624 - val_loss: 0.1186 - val_accuracy: 0.9585
# Epoch 298/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.0966 - accuracy: 0.9688
# Epoch 298: val_loss did not improve from 0.10206
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0951 - accuracy: 0.9687 - val_loss: 0.1104 - val_accuracy: 0.9629
# Epoch 299/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.1203 - accuracy: 0.9596
# Epoch 299: val_loss did not improve from 0.10206
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1208 - accuracy: 0.9602 - val_loss: 0.1391 - val_accuracy: 0.9585
# Epoch 300/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.1304 - accuracy: 0.9568
# Epoch 300: val_loss did not improve from 0.10206
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1304 - accuracy: 0.9568 - val_loss: 0.1341 - val_accuracy: 0.9541
# Epoch 301/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1197 - accuracy: 0.9581
# Epoch 301: val_loss did not improve from 0.10206
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1194 - accuracy: 0.9582 - val_loss: 0.1153 - val_accuracy: 0.9651
# Epoch 302/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.1019 - accuracy: 0.9661
# Epoch 302: val_loss did not improve from 0.10206
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0986 - accuracy: 0.9671 - val_loss: 0.1374 - val_accuracy: 0.9651
# Epoch 303/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0912 - accuracy: 0.9701
# Epoch 303: val_loss did not improve from 0.10206
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0939 - accuracy: 0.9693 - val_loss: 0.1162 - val_accuracy: 0.9607
# Epoch 304/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1303 - accuracy: 0.9565
# Epoch 304: val_loss did not improve from 0.10206
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1299 - accuracy: 0.9566 - val_loss: 0.1217 - val_accuracy: 0.9607
# Epoch 305/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1087 - accuracy: 0.9657
# Epoch 305: val_loss did not improve from 0.10206
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1089 - accuracy: 0.9651 - val_loss: 0.1696 - val_accuracy: 0.9563
# Epoch 306/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.0861 - accuracy: 0.9694
# Epoch 306: val_loss improved from 0.10206 to 0.09793, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0912 - accuracy: 0.9682 - val_loss: 0.0979 - val_accuracy: 0.9672
# Epoch 307/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.0917 - accuracy: 0.9707
# Epoch 307: val_loss did not improve from 0.09793
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0925 - accuracy: 0.9701 - val_loss: 0.1411 - val_accuracy: 0.9585
# Epoch 308/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.0890 - accuracy: 0.9736
# Epoch 308: val_loss did not improve from 0.09793
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0903 - accuracy: 0.9721 - val_loss: 0.1054 - val_accuracy: 0.9607
# Epoch 309/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.1014 - accuracy: 0.9674
# Epoch 309: val_loss did not improve from 0.09793
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1002 - accuracy: 0.9676 - val_loss: 0.1415 - val_accuracy: 0.9651
# Epoch 310/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.1062 - accuracy: 0.9648
# Epoch 310: val_loss did not improve from 0.09793
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1059 - accuracy: 0.9657 - val_loss: 0.1432 - val_accuracy: 0.9651
# Epoch 311/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.1218 - accuracy: 0.9564
# Epoch 311: val_loss did not improve from 0.09793
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1230 - accuracy: 0.9563 - val_loss: 0.1171 - val_accuracy: 0.9585
# Epoch 312/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.1227 - accuracy: 0.9567
# Epoch 312: val_loss did not improve from 0.09793
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1170 - accuracy: 0.9593 - val_loss: 0.1332 - val_accuracy: 0.9607
# Epoch 313/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0973 - accuracy: 0.9657
# Epoch 313: val_loss did not improve from 0.09793
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0973 - accuracy: 0.9657 - val_loss: 0.1068 - val_accuracy: 0.9672
# Epoch 314/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.0924 - accuracy: 0.9688
# Epoch 314: val_loss did not improve from 0.09793
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0941 - accuracy: 0.9682 - val_loss: 0.1309 - val_accuracy: 0.9607
# Epoch 315/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0862 - accuracy: 0.9690
# Epoch 315: val_loss improved from 0.09793 to 0.09666, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0867 - accuracy: 0.9690 - val_loss: 0.0967 - val_accuracy: 0.9760
# Epoch 316/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.1055 - accuracy: 0.9635
# Epoch 316: val_loss did not improve from 0.09666
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1024 - accuracy: 0.9640 - val_loss: 0.1179 - val_accuracy: 0.9629
# Epoch 317/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.0905 - accuracy: 0.9710
# Epoch 317: val_loss did not improve from 0.09666
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0904 - accuracy: 0.9707 - val_loss: 0.1120 - val_accuracy: 0.9716
# Epoch 318/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.0995 - accuracy: 0.9658
# Epoch 318: val_loss did not improve from 0.09666
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0949 - accuracy: 0.9682 - val_loss: 0.1302 - val_accuracy: 0.9585
# Epoch 319/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.1136 - accuracy: 0.9600
# Epoch 319: val_loss did not improve from 0.09666
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1134 - accuracy: 0.9591 - val_loss: 0.1497 - val_accuracy: 0.9563
# Epoch 320/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1012 - accuracy: 0.9660
# Epoch 320: val_loss did not improve from 0.09666
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1034 - accuracy: 0.9657 - val_loss: 0.1157 - val_accuracy: 0.9672
# Epoch 321/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.0989 - accuracy: 0.9658
# Epoch 321: val_loss did not improve from 0.09666
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1005 - accuracy: 0.9668 - val_loss: 0.1141 - val_accuracy: 0.9694
# Epoch 322/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.1102 - accuracy: 0.9606
# Epoch 322: val_loss improved from 0.09666 to 0.08291, saving model to C:\Users\taemi\capstone\best_weight_model\default4.h5
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1115 - accuracy: 0.9602 - val_loss: 0.0829 - val_accuracy: 0.9738
# Epoch 323/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0925 - accuracy: 0.9707
# Epoch 323: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0930 - accuracy: 0.9704 - val_loss: 0.1320 - val_accuracy: 0.9629
# Epoch 324/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0969 - accuracy: 0.9690
# Epoch 324: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0971 - accuracy: 0.9690 - val_loss: 0.1060 - val_accuracy: 0.9672
# Epoch 325/1000
# 6/8 [=====================>........] - ETA: 0s - loss: 0.0878 - accuracy: 0.9704
# Epoch 325: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0900 - accuracy: 0.9698 - val_loss: 0.1157 - val_accuracy: 0.9672
# Epoch 326/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0890 - accuracy: 0.9690
# Epoch 326: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0897 - accuracy: 0.9687 - val_loss: 0.1137 - val_accuracy: 0.9672
# Epoch 327/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0987 - accuracy: 0.9690
# Epoch 327: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0981 - accuracy: 0.9693 - val_loss: 0.1405 - val_accuracy: 0.9607
# Epoch 328/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0907 - accuracy: 0.9718
# Epoch 328: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0908 - accuracy: 0.9718 - val_loss: 0.0949 - val_accuracy: 0.9672
# Epoch 329/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0891 - accuracy: 0.9679
# Epoch 329: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0899 - accuracy: 0.9674 - val_loss: 0.1195 - val_accuracy: 0.9694
# Epoch 330/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0915 - accuracy: 0.9682
# Epoch 330: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0911 - accuracy: 0.9685 - val_loss: 0.1487 - val_accuracy: 0.9563
# Epoch 331/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0883 - accuracy: 0.9704
# Epoch 331: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0883 - accuracy: 0.9704 - val_loss: 0.1238 - val_accuracy: 0.9694
# Epoch 332/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0947 - accuracy: 0.9668
# Epoch 332: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0946 - accuracy: 0.9668 - val_loss: 0.1087 - val_accuracy: 0.9694
# Epoch 333/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0897 - accuracy: 0.9696
# Epoch 333: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0900 - accuracy: 0.9696 - val_loss: 0.1195 - val_accuracy: 0.9672
# Epoch 334/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0856 - accuracy: 0.9721
# Epoch 334: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0860 - accuracy: 0.9718 - val_loss: 0.1508 - val_accuracy: 0.9585
# Epoch 335/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0952 - accuracy: 0.9676
# Epoch 335: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0948 - accuracy: 0.9679 - val_loss: 0.0907 - val_accuracy: 0.9760
# Epoch 336/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0894 - accuracy: 0.9696
# Epoch 336: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0889 - accuracy: 0.9698 - val_loss: 0.1319 - val_accuracy: 0.9672
# Epoch 337/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0857 - accuracy: 0.9713
# Epoch 337: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0863 - accuracy: 0.9710 - val_loss: 0.1030 - val_accuracy: 0.9651
# Epoch 338/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0838 - accuracy: 0.9729
# Epoch 338: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0835 - accuracy: 0.9732 - val_loss: 0.1130 - val_accuracy: 0.9694
# Epoch 339/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0809 - accuracy: 0.9713
# Epoch 339: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0810 - accuracy: 0.9712 - val_loss: 0.1206 - val_accuracy: 0.9651
# Epoch 340/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0852 - accuracy: 0.9718
# Epoch 340: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0846 - accuracy: 0.9721 - val_loss: 0.1042 - val_accuracy: 0.9694
# Epoch 341/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0908 - accuracy: 0.9693
# Epoch 341: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0908 - accuracy: 0.9693 - val_loss: 0.1416 - val_accuracy: 0.9629
# Epoch 342/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0839 - accuracy: 0.9727
# Epoch 342: val_loss did not improve from 0.08291
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0840 - accuracy: 0.9726 - val_loss: 0.1068 - val_accuracy: 0.9716
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0852 - accuracy: 0.9702
# Pre-training accuracy: 97.0238%

# %%
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
model = load_model("C:\\Users\\taemi\\capstone\\best_weight_model\\default4.h5")
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", round(score[1]*100, 5), "%")
score = model.evaluate(x_val, y_val, verbose=0)
print("Validation Accuracy: ", round(score[1]*100, 5), "%")
score = model.evaluate(x_test, y_test, verbose=0)
print("Test Accuracy: ", round(score[1]*100, 5), "%")

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))

plt.figure(1)
plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure(2)
plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
# Out:
# Training Accuracy:  98.58921 %
# Validation Accuracy:  97.37991 %
# Test Accuracy:  97.81746 %

# %%
def print_prediction(file_name):
    prediction_feature = mel_extraction(file_name) 
    prediction_feature = prediction_feature.reshape(1, num_rows, num_columns, num_channels)
    
    y_prob = model.predict(prediction_feature)
    predicted_vector = y_prob.argmax(axis=-1)
    
    predicted_class = le.inverse_transform(predicted_vector) 
    print("The predicted class is:", predicted_class[0], '\n') 


    predicted_proba_vector = model.predict(prediction_feature) 
    predicted_proba = predicted_proba_vector[0]
    
    for i in range(len(predicted_proba)): 
        category = le.inverse_transform(np.array([i]))
        print(category[0], "\t\t : ", format(predicted_proba[i], '.32f') )

# %%
def predict_prob(number):
  return [number[0],1-number[0]]

# %%
filename = 'C:\\Users\\taemi\\Documents\\소리 녹음\\bell.wav'
print_prediction(filename)
# Out:
# WARNING:tensorflow:5 out of the last 27 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000210EB4B6F70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 50ms/step
# The predicted class is: meow
#
# 1/1 [==============================] - 0s 12ms/step
# babycry 		 :  0.04494417831301689147949218750000
# car_horn 		 :  0.00047556534991599619388580322266
# dogbark 		 :  0.00004640027691493742167949676514
# door 		 :  0.00000000001357331521484317349291
# doorbell1 		 :  0.26345536112785339355468750000000
# doorbell2 		 :  0.12184032797813415527343750000000
# glassbreak 		 :  0.00000715490114089334383606910706
# knock 		 :  0.00000000000004055236981176206512
# meow 		 :  0.56647104024887084960937500000000
# phonevibrate 		 :  0.00000000013917590691026049398715
# scream 		 :  0.00124118349049240350723266601562
# siren 		 :  0.00151877535972744226455688476562
